# %%
from pytfa.io.json import load_json_model
from cobra import Reaction

redgem_file_name = 'reduced_model_ETC_core_20240816-155234.json'
reduced_model = load_json_model(redgem_file_name)
reduced_model.optimize()

# remove sinks if there are still any
reduced_model.remove_reactions([rxn.id for rxn in reduced_model.reactions if 'sink' in rxn.id])

# Thermo for sodium
reduced_model.thermo_data['metabolites']['cpd00971']['deltaGf_std'] = 1.0
reduced_model.thermo_data['metabolites']['cpd00971']['deltaGf_err'] = 0.1
reduced_model.thermo_data['metabolites']['cpd00971']['error']  = 'Nil'


reduced_model.solver.configuration.tolerances.feasibility = 1e-9
reduced_model.solver.configuration.tolerances.optimality = 1e-9
reduced_model.solver.configuration.tolerances.integrality = 1e-9
# Out:
# 2024-12-16 10:43:14,739 - thermomodel_Recon3thermoCurated - INFO - # Model initialized with units kcal/mol and temperature 298.15 K

# %%
# Resting membrane potential
reduced_model.compartments['c']['membranePot']['e'] = 60
reduced_model.compartments['e']['membranePot']['c'] = -60
# Resting mitochondrial membrane potential
reduced_model.compartments['m']['membranePot']['c'] = 150
reduced_model.compartments['c']['membranePot']['m'] = -150

# %%
from cobra import Metabolite

# Add mitochondrial sodium
na1_m = Metabolite('na1_m')
na1_m.charge = 1
na1_m.compartment = 'm'
na1_m.formula = 'Na'
na1_m.name = 'Sodium'
na1_m.annotation['seed_id'] = 'cpd00971'

# No pKa for sodium
reduced_model.thermo_data['metabolites']['cpd00971']['pKa']  = []

reduced_model.add_metabolites([na1_m,])

# Model the establishment of mitochondrial membrane potential
na_h_antiport = Reaction('NaH_antiport')
reduced_model.add_reactions([ na_h_antiport,])
na_h_antiport.reaction = 'na1_m + h_c <=> na1_c + h_m'

# Sodium channel
na1_channel = Reaction('Na_channel')
reduced_model.add_reactions([ na1_channel,])
na1_channel.reaction = 'na1_c <=> na1_m'

# %%
# Remodel the FAPT1t reactions substitute sodium for protons 
FATP1t = reduced_model.reactions.get_by_id('FATP1t')
FATP1t.add_metabolites({reduced_model.metabolites.na1_c: 1, 
                        reduced_model.metabolites.na1_e: -1 ,
                        reduced_model.metabolites.h_c: -1, 
                        reduced_model.metabolites.h_e: 1})

# %%
# Add extracellular pyruvate
pyr_e = Metabolite('pyr_e')
pyr_e.charge = -1
pyr_e.compartment = 'e'
pyr_e.formula = 'C3H3O3'
pyr_e.name = 'Pyruvate'
pyr_e.annotation['seed_id'] = 'cpd00020'

reduced_model.add_metabolites([pyr_e,])

# Add pyruvate transport
pyr_t = Reaction('PYRt')
reduced_model.add_reactions([ pyr_t,])
pyr_t.reaction = 'pyr_e + h_e <=> pyr_c + h_c'

# Add pyruvate exchange
pyr_exchange = Reaction('EX_pyr_e')
reduced_model.add_reactions([ pyr_exchange,])
pyr_exchange.reaction = 'pyr_e <=>'

# %%
# Check stuff
reduced_model.metabolites.pmtcoa_m
# Out:
# <Metabolite pmtcoa_m at 0x7f9609a47700>

# %%
# We add the full beta oxidation pathway insread of the simplified one
# add all the CoA species between C16-CoA and C2-CoA

# C16 CoA -> C14 CoA

# Alcyl Coa alredy in the model
# Enoyl-CoA
c16_enoyl_coa = Metabolite('c16enoylcoa_m')
c16_enoyl_coa.charge = -4
c16_enoyl_coa.compartment = 'm'
c16_enoyl_coa.formula = 'C37H60N7O17P3S'
c16_enoyl_coa.name = '7-Hexadecenoyl Coenzyme A'
c16_enoyl_coa.annotation['seed_id'] = '7-Hexadecenoyl Coenzyme A'

# Hydroxyacyl-CoA
c16_hydroxyacyl_coa = Metabolite('c16hydroxyacylcoa_m')
c16_hydroxyacyl_coa.charge = -4
c16_hydroxyacyl_coa.compartment = 'm'
c16_hydroxyacyl_coa.formula = 'C37H62N7O18P3S'
c16_hydroxyacyl_coa.name = '3S-Hydroxyhexadecanoyl Coenzyme A'
c16_hydroxyacyl_coa.annotation['seed_id'] = 'cpd03113'

# Ketoacyl-CoA
c16_ketoacyl_coa = Metabolite('c16ketoacylcoa_m')
c16_ketoacyl_coa.charge = -4
c16_ketoacyl_coa.compartment = 'm'
c16_ketoacyl_coa.formula = 'C37H60N7O18P3S'
c16_ketoacyl_coa.name = '3-Oxopalmitoyl Coenzyme A'
c16_ketoacyl_coa.annotation['seed_id'] = 'cpd03114'

# Alcyl n-2 CoA
c14_coa = Metabolite('c14coa_m')
c14_coa.charge = -4
c14_coa.compartment = 'm'
c14_coa.formula = 'C35H58N7O17P3S'
c14_coa.name = 'Myristoyl-CoA'
c14_coa.annotation['seed_id'] = 'cpd01695'

# Add the metabolites
reduced_model.add_metabolites([c16_enoyl_coa, c16_hydroxyacyl_coa, c16_ketoacyl_coa, c14_coa,])

# Add the reactions
# Acyl-CoA dehydrogenase
ACOAD16m = Reaction('ACOAD16m')
reduced_model.add_reactions([ ACOAD16m,])
ACOAD16m.reaction = 'pmtcoa_m + fad_m <=> c16enoylcoa_m + fadh2_m'

# Enoyl-CoA hydratase
ECH16m = Reaction('ECH16m')
reduced_model.add_reactions([ ECH16m,])
ECH16m.reaction = 'c16enoylcoa_m + h2o_m <=> c16hydroxyacylcoa_m'

# Ketoacyl-CoA dehydrogenase
KAS16m = Reaction('KAS16m')
reduced_model.add_reactions([ KAS16m,])
KAS16m.reaction = 'c16hydroxyacylcoa_m + nad_m <=> c16ketoacylcoa_m + nadh_m + h_m'

# Thiolase
THIO16m = Reaction('THIO16m')
reduced_model.add_reactions([ THIO16m,])
THIO16m.reaction = 'c16ketoacylcoa_m + coa_m <=> accoa_m + c14coa_m'

# %%
# C14 CoA -> C12 CoA

# Enoyl-CoA
c14_enoyl_coa = Metabolite('c14enoylcoa_m')
c14_enoyl_coa.charge = -4
c14_enoyl_coa.compartment = 'm'
c14_enoyl_coa.formula = 'C35H56N7O17P3S'
c14_enoyl_coa.name = '5-Tetradecenoyl Coenzyme A'
c14_enoyl_coa.annotation['seed_id'] = 'cpd03127'

# Hydroxyacyl-CoA
c14_hydroxyacyl_coa = Metabolite('c14hydroxyacylcoa_m')
c14_hydroxyacyl_coa.charge = -4
c14_hydroxyacyl_coa.compartment = 'm'
c14_hydroxyacyl_coa.formula = 'C35H58N7O18P3S'
c14_hydroxyacyl_coa.name = '3S-Hydroxytetradecanoyl Coenzyme A'
c14_hydroxyacyl_coa.annotation['seed_id'] = 'cpd03115'

# Ketoacyl-CoA
c14_ketoacyl_coa = Metabolite('c14ketoacylcoa_m')
c14_ketoacyl_coa.charge = -4
c14_ketoacyl_coa.compartment = 'm'
c14_ketoacyl_coa.formula = 'C35H56N7O18P3S'
c14_ketoacyl_coa.name = '3-Oxotetradecanoyl-CoA'
c14_ketoacyl_coa.annotation['seed_id'] = 'cpd12689'

# Alcyl n-2 CoA
c12_coa = Metabolite('c12coa_m')
c12_coa.charge = -4
c12_coa.compartment = 'm'
c12_coa.formula = 'C33H54N7O17P3S'
c12_coa.name = 'Dodecanoyl-CoA'
c12_coa.annotation['seed_id'] = 'cpd01260'

# Add the metabolites
reduced_model.add_metabolites([c14_enoyl_coa, c14_hydroxyacyl_coa, c14_ketoacyl_coa, c12_coa,])

# Add the reactions
# Acyl-CoA dehydrogenase
ACOAD14m = Reaction('ACOAD14m')
reduced_model.add_reactions([ ACOAD14m,])
ACOAD14m.reaction = 'c14coa_m + fad_m <=> c14enoylcoa_m + fadh2_m'

# Enoyl-CoA hydratase
ECH14m = Reaction('ECH14m')
reduced_model.add_reactions([ ECH14m,])
ECH14m.reaction = 'c14enoylcoa_m + h2o_m <=> c14hydroxyacylcoa_m'

# Ketoacyl-CoA dehydrogenase
KAS14m = Reaction('KAS14m')
reduced_model.add_reactions([ KAS14m,])
KAS14m.reaction = 'c14hydroxyacylcoa_m + nad_m <=> c14ketoacylcoa_m + nadh_m + h_m'

# Thiolase
THIO14m = Reaction('THIO14m')
reduced_model.add_reactions([ THIO14m,])
THIO14m.reaction = 'c14ketoacylcoa_m + coa_m <=> accoa_m + c12coa_m'

# %%
# C12 CoA -> C10 CoA

# Enoyl-CoA
c12_enoyl_coa = Metabolite('c12enoylcoa_m')
c12_enoyl_coa.charge = -4
c12_enoyl_coa.compartment = 'm'
c12_enoyl_coa.formula = 'C33H52N7O17P3S'
c12_enoyl_coa.name = 'Trans-Dodec-2-Enoyl Coenzyme A'
c12_enoyl_coa.annotation['seed_id'] = 'cpd02060'

# Hydroxyacyl-CoA
c12_hydroxyacyl_coa = Metabolite('c12hydroxyacylcoa_m')
c12_hydroxyacyl_coa.charge = -4
c12_hydroxyacyl_coa.compartment = 'm'
c12_hydroxyacyl_coa.formula = 'C33H54N7O18P3S'
c12_hydroxyacyl_coa.name = '(S)-3-Hydroxydodecanoyl Coenzyme A'
c12_hydroxyacyl_coa.annotation['seed_id'] = 'cpd03116'

# Ketoacyl-CoA
c12_ketoacyl_coa = Metabolite('c12ketoacylcoa_m')
c12_ketoacyl_coa.charge = -4
c12_ketoacyl_coa.compartment = 'm'
c12_ketoacyl_coa.formula = 'C33H52N7O18P3S'
c12_ketoacyl_coa.name = '3-Oxododecanoyl-CoA'
c12_ketoacyl_coa.annotation['seed_id'] = 'cpd03117'

# Alcyl n-2 CoA
c10_coa = Metabolite('c10coa_m')
c10_coa.charge = -4
c10_coa.compartment = 'm'
c10_coa.formula = 'C31H50N7O17P3S'
c10_coa.name = 'Decanoyl-CoA'
c10_coa.annotation['seed_id'] = 'cpd03128'

# Add the metabolites
reduced_model.add_metabolites([c12_enoyl_coa, c12_hydroxyacyl_coa, c12_ketoacyl_coa, c10_coa,])

# Add the reactions
# Acyl-CoA dehydrogenase
ACOAD12m = Reaction('ACOAD12m')
reduced_model.add_reactions([ ACOAD12m,])
ACOAD12m.reaction = 'c12coa_m + fad_m <=> c12enoylcoa_m + fadh2_m'

# Enoyl-CoA hydratase
ECH12m = Reaction('ECH12m')
reduced_model.add_reactions([ ECH12m,])
ECH12m.reaction = 'c12enoylcoa_m + h2o_m <=> c12hydroxyacylcoa_m'

# Ketoacyl-CoA dehydrogenase
KAS12m = Reaction('KAS12m')
reduced_model.add_reactions([ KAS12m,])
KAS12m.reaction = 'c12hydroxyacylcoa_m + nad_m <=> c12ketoacylcoa_m + nadh_m + h_m'

# Thiolase
THIO12m = Reaction('THIO12m')
reduced_model.add_reactions([ THIO12m,])
THIO12m.reaction = 'c12ketoacylcoa_m + coa_m <=> accoa_m + c10coa_m'

# %%
# C10 CoA -> C8 CoA

# Enoyl-CoA
c10_enoyl_coa = Metabolite('c10enoylcoa_m')
c10_enoyl_coa.charge = -4
c10_enoyl_coa.compartment = 'm'
c10_enoyl_coa.formula = 'C31H48N7O17P3S'
c10_enoyl_coa.name = 'Trans-Dec-2-Enoyl Coenzyme A'
c10_enoyl_coa.annotation['seed_id'] = 'cpd03129'

# Hydroxyacyl-CoA
c10_hydroxyacyl_coa = Metabolite('c10hydroxyacylcoa_m')
c10_hydroxyacyl_coa.charge = -4
c10_hydroxyacyl_coa.compartment = 'm'
c10_hydroxyacyl_coa.formula = 'C31H50N7O18P3S'
c10_hydroxyacyl_coa.name = '(S)-3-Hydroxydecanoyl Coenzyme A'
c10_hydroxyacyl_coa.annotation['seed_id'] = 'cpd03118'

# Ketoacyl-CoA
c10_ketoacyl_coa = Metabolite('c10ketoacylcoa_m')
c10_ketoacyl_coa.charge = -4
c10_ketoacyl_coa.compartment = 'm'
c10_ketoacyl_coa.formula = 'C31H48N7O18P3S'
c10_ketoacyl_coa.name = '3-Oxodecanoyl Coenzyme A'
c10_ketoacyl_coa.annotation['seed_id'] = 'cpd03119'

# Alcyl n-2 CoA
c8_coa = Metabolite('c8coa_m')
c8_coa.charge = -4
c8_coa.compartment = 'm'
c8_coa.formula = 'C29H46N7O17P3S'
c8_coa.name = 'Octanoyl-CoA'
c8_coa.annotation['seed_id'] = 'cpd01335'

# Add the metabolites
reduced_model.add_metabolites([c10_enoyl_coa, c10_hydroxyacyl_coa, c10_ketoacyl_coa, c8_coa,])

# Add the reactions
# Acyl-CoA dehydrogenase
ACOAD10m = Reaction('ACOAD10m')
reduced_model.add_reactions([ ACOAD10m,])
ACOAD10m.reaction = 'c10coa_m + fad_m <=> c10enoylcoa_m + fadh2_m'

# Enoyl-CoA hydratase
ECH10m = Reaction('ECH10m')
reduced_model.add_reactions([ ECH10m,])
ECH10m.reaction = 'c10enoylcoa_m + h2o_m <=> c10hydroxyacylcoa_m'

# Ketoacyl-CoA dehydrogenase
KAS10m = Reaction('KAS10m')
reduced_model.add_reactions([ KAS10m,])
KAS10m.reaction = 'c10hydroxyacylcoa_m + nad_m <=> c10ketoacylcoa_m + nadh_m + h_m'

# Thiolase
THIO10m = Reaction('THIO10m')
reduced_model.add_reactions([ THIO10m,])
THIO10m.reaction = 'c10ketoacylcoa_m + coa_m <=> accoa_m + c8coa_m'

# %%
# C8 CoA -> C6 CoA

# Enoyl-CoA
c8_enoyl_coa = Metabolite('c8enoylcoa_m')
c8_enoyl_coa.charge = -4
c8_enoyl_coa.compartment = 'm'
c8_enoyl_coa.formula = 'C29H44N7O17P3S'
c8_enoyl_coa.name = '(2E)-Octenoyl Coenzyme A'
c8_enoyl_coa.annotation['seed_id'] = 'cpd03130'

# Hydroxyacyl-CoA
c8_hydroxyacyl_coa = Metabolite('c8hydroxyacylcoa_m')
c8_hydroxyacyl_coa.charge = -4
c8_hydroxyacyl_coa.compartment = 'm'
c8_hydroxyacyl_coa.formula = 'C29H46N7O18P3S'
c8_hydroxyacyl_coa.name = '(S)-3-Hydroxyoctanoyl Coenzyme A'
c8_hydroxyacyl_coa.annotation['seed_id'] = 'cpd03120'

# Ketoacyl-CoA
c8_ketoacyl_coa = Metabolite('c8ketoacylcoa_m')
c8_ketoacyl_coa.charge = -4
c8_ketoacyl_coa.compartment = 'm'
c8_ketoacyl_coa.formula = 'C29H44N7O18P3S'
c8_ketoacyl_coa.name = '3-Oxo-Octanoyl Coenzyme A'
c8_ketoacyl_coa.annotation['seed_id'] = 'cpd03121'

# Alcyl n-2 CoA
c6_coa = Metabolite('c6coa_m')
c6_coa.charge = -4
c6_coa.compartment = 'm'
c6_coa.formula = 'C27H42N7O17P3S'
c6_coa.name = 'Hexanoyl-CoA'
c6_coa.annotation['seed_id'] = 'cpd03124'

# Add the metabolites
reduced_model.add_metabolites([c8_enoyl_coa, c8_hydroxyacyl_coa, c8_ketoacyl_coa, c6_coa,])

# Add the reactions
# Acyl-CoA dehydrogenase
ACOAD8m = Reaction('ACOAD8m')
reduced_model.add_reactions([ ACOAD8m,])
ACOAD8m.reaction = 'c8coa_m + fad_m <=> c8enoylcoa_m + fadh2_m'

# Enoyl-CoA hydratase
ECH8m = Reaction('ECH8m')
reduced_model.add_reactions([ ECH8m,])
ECH8m.reaction = 'c8enoylcoa_m + h2o_m <=> c8hydroxyacylcoa_m'

# Ketoacyl-CoA dehydrogenase
KAS8m = Reaction('KAS8m')
reduced_model.add_reactions([ KAS8m,])
KAS8m.reaction = 'c8hydroxyacylcoa_m + nad_m <=> c8ketoacylcoa_m + nadh_m + h_m'

# Thiolase
THIO8m = Reaction('THIO8m')
reduced_model.add_reactions([ THIO8m,])
THIO8m.reaction = 'c8ketoacylcoa_m + coa_m <=> accoa_m + c6coa_m'

# %%
# C6 CoA -> C4 CoA

# Enoyl-CoA
c6_enoyl_coa = Metabolite('c6enoylcoa_m')
c6_enoyl_coa.charge = -4
c6_enoyl_coa.compartment = 'm'
c6_enoyl_coa.formula = 'C27H40N7O17P3S'
c6_enoyl_coa.name = 'Trans-Hex-2-Enoyl Coenzyme A'
c6_enoyl_coa.annotation['seed_id'] = 'cpd03125'

# Hydroxyacyl-CoA
c6_hydroxyacyl_coa = Metabolite('c6hydroxyacylcoa_m')
c6_hydroxyacyl_coa.charge = -4
c6_hydroxyacyl_coa.compartment = 'm'
c6_hydroxyacyl_coa.formula = 'C27H42N7O18P3S'
c6_hydroxyacyl_coa.name = '(S)-3-Hydroxyhexanoyl Coenzyme A'
c6_hydroxyacyl_coa.annotation['seed_id'] = 'cpd03122'

# Ketoacyl-CoA
c6_ketoacyl_coa = Metabolite('c6ketoacylcoa_m')
c6_ketoacyl_coa.charge = -4
c6_ketoacyl_coa.compartment = 'm'
c6_ketoacyl_coa.formula = 'C27H40N7O18P3S'
c6_ketoacyl_coa.name = '3-Oxohexanoyl Coenzyme A'
c6_ketoacyl_coa.annotation['seed_id'] = 'cpd03123'

# Alcyl n-2 CoA
c4_coa = Metabolite('c4coa_m')
c4_coa.charge = -4
c4_coa.compartment = 'm'
c4_coa.formula = 'C25H38N7O17P3S'
c4_coa.name = 'Butanoyl-CoA'
c4_coa.annotation['seed_id'] = 'cpd00120'

# Add the metabolites
reduced_model.add_metabolites([c6_enoyl_coa, c6_hydroxyacyl_coa, c6_ketoacyl_coa, c4_coa,])

# Add the reactions
# Acyl-CoA dehydrogenase
ACOAD6m = Reaction('ACOAD6m')
reduced_model.add_reactions([ ACOAD6m,])
ACOAD6m.reaction = 'c6coa_m + fad_m <=> c6enoylcoa_m + fadh2_m'

# Enoyl-CoA hydratase
ECH6m = Reaction('ECH6m')
reduced_model.add_reactions([ ECH6m,])
ECH6m.reaction = 'c6enoylcoa_m + h2o_m <=> c6hydroxyacylcoa_m'

# Ketoacyl-CoA dehydrogenase
KAS6m = Reaction('KAS6m')
reduced_model.add_reactions([ KAS6m,])
KAS6m.reaction = 'c6hydroxyacylcoa_m + nad_m <=> c6ketoacylcoa_m + nadh_m + h_m'

# Thiolase
THIO6m = Reaction('THIO6m')
reduced_model.add_reactions([ THIO6m,])
THIO6m.reaction = 'c6ketoacylcoa_m + coa_m <=> accoa_m + c4coa_m'

# %%
# C4 CoA -> C2 CoA

# Enoyl-CoA
c4_enoyl_coa = Metabolite('c4enoylcoa_m')
c4_enoyl_coa.charge = -4
c4_enoyl_coa.compartment = 'm'
c4_enoyl_coa.formula = 'C25H36N7O17P3S'
c4_enoyl_coa.name = 'Crotonoyl Coenzyme A'
c4_enoyl_coa.annotation['seed_id'] = 'cpd00650'

# Hydroxyacyl-CoA
c4_hydroxyacyl_coa = Metabolite('c4hydroxyacylcoa_m')
c4_hydroxyacyl_coa.charge = -4
c4_hydroxyacyl_coa.compartment = 'm'
c4_hydroxyacyl_coa.formula = 'C25H38N7O18P3S'
c4_hydroxyacyl_coa.name = '(S)-3-Hydroxybutanoyl Coenzyme A'
c4_hydroxyacyl_coa.annotation['seed_id'] = 'cpd02234'

# Ketoacyl-CoA -> Acetoacetyl-CoA (Already in the model)

# Alcyl n-2 CoA 0> Acetyl-CoA (Already in the model)

# Add the metabolites
reduced_model.add_metabolites([c4_enoyl_coa, c4_hydroxyacyl_coa,])

# Add the reactions
# Acyl-CoA dehydrogenase
ACOAD4m = Reaction('ACOAD4m')
reduced_model.add_reactions([ ACOAD4m,])
ACOAD4m.reaction = 'c4coa_m + fad_m <=> c4enoylcoa_m + fadh2_m'

# Enoyl-CoA hydratase
ECH4m = Reaction('ECH4m')
reduced_model.add_reactions([ ECH4m,])
ECH4m.reaction = 'c4enoylcoa_m + h2o_m <=> c4hydroxyacylcoa_m'

# Ketoacyl-CoA dehydrogenase
KAS4m = Reaction('KAS4m')
reduced_model.add_reactions([ KAS4m,])
KAS4m.reaction = 'c4hydroxyacylcoa_m + nad_m <=> aacoa_m + nadh_m + h_m'

# %%
# Try to close FAOXC160
reduced_model.reactions.get_by_id('FAOXC160').bounds = (0, 0)
reduced_model.optimize()
# Out:
# <Solution 173.379 at 0x7f96329394f0>

# %%
# Remove constraints of type ModelConstraints 
from tqdm import tqdm

cons_subclass = reduced_model._cons_kinds['ModelConstraint']
for cons in tqdm(cons_subclass):
    reduced_model.remove_constraint(cons)

reduced_model.repair()
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 2367.52it/s]

# %%
# Set h_c to h_i 
h_i = reduced_model.metabolites.h_i
h_c = reduced_model.metabolites.h_c
for r in reduced_model.reactions:
    if h_i in r.metabolites:
        stoich = r.metabolites[h_i]
        r.add_metabolites({h_i: -stoich, h_c: stoich})

reduced_model.prepare()
reduced_model.convert()
# Out:
# 2024-12-16 10:43:15,236 - thermomodel_Recon3thermoCurated - INFO - # Model preparation starting...
# 2024-12-16 10:43:15,276 - thermomodel_Recon3thermoCurated - INFO - # Model preparation done.
# 2024-12-16 10:43:15,277 - thermomodel_Recon3thermoCurated - INFO - # Model conversion starting...
# 2024-12-16 10:43:15,482 - thermomodel_Recon3thermoCurated - INFO - # Model conversion done.
# 2024-12-16 10:43:15,483 - thermomodel_Recon3thermoCurated - INFO - # Updating cobra_model variables...
# 2024-12-16 10:43:15,485 - thermomodel_Recon3thermoCurated - INFO - # cobra_model variables are up-to-date

# %%
# Refine Glycolysis corrected delta G constraints from Lehninger:
# Units are in kJ/mol
glycolysis_thermodynamics = {
    'HEX1': -16.7,
    'PGI': 1.7,
    'PFK': -14.9,
    'FBA': 23.8,
    'TPI': 5.6, # Equilibrator value
    'GAPD': 6.3,
    'PGK': 18.8,
    'PGM': 4.4, 
    'ENO': 7.5,
    'PYK': -31.4,
    'LDH_L': 25.1,
    'LDH_Lm': 33.1,
    }

# Converstion to kcal/mol
scaling = 0.239006
for r_id, dg in glycolysis_thermodynamics.items():
    dgo = reduced_model.delta_gstd.get_by_id(r_id).variable
    try:
        dgo.ub = dg * scaling + 0.1
        dgo.lb = dg * scaling - 0.1
    except ValueError:
        dgo.lb = dg * scaling - 0.1
        dgo.ub = dg * scaling + 0.1

    reduced_model.optimize()
    print(f"{r_id} : {dgo.lb} < {dgo.primal} < {dgo.ub} kcal/mol")


sol = reduced_model.optimize()
# Out:
# HEX1 : -4.0914002 < -4.0914002 < -3.8914001999999996 kcal/mol
# PGI : 0.3063102 < 0.3063102 < 0.5063102 kcal/mol
# PFK : -3.6611894 < -3.6611894 < -3.4611894 kcal/mol
# FBA : 5.5883428 < 5.5883428 < 5.7883428 kcal/mol
# TPI : 1.2384335999999998 < 1.292545 < 1.4384336 kcal/mol
# GAPD : 1.4057377999999998 < 1.4057377999999998 < 1.6057378 kcal/mol
# PGK : 4.3933128 < 4.3933128 < 4.5933128 kcal/mol
# PGM : 0.9516264 < 1.1516264 < 1.1516264 kcal/mol
# ENO : 1.692545 < 1.692545 < 1.8925450000000001 kcal/mol
# PYK : -7.6047883999999994 < -7.6047883999999994 < -7.4047884 kcal/mol
# LDH_L : 5.899050600000001 < 6.0990506 < 6.0990506 kcal/mol
# LDH_Lm : 7.8110986 < 7.8110986 < 8.0110986 kcal/mol

# %%
reduced_model.reactions.FAOXC160.thermo
# Out:
# {'isTrans': False,
#  'computed': True,
#  'deltaGR': -44.88327081916579,
#  'deltaGRerr': 19.0660846174562}

# %%
# Refine TCA corrected delta G constraints from Lehninger:
# Units are in kJ/mol
tca_thermodynamics = {
    'PDHm' : -33.4,
    'CSm' : -32.3,
    'ACONTm' : 13.3,
    'ICDHxm' : 10.0, # Equilibrator value ?!?!
    'AKGDm' : -33.5,
    'SUCOAS1m' : -2.9,
    'r0509' : -24.1, # Equilibrator value (EC: 1.3.5.1) 
    'FUMm': -3.8,
    'MDHm' : 29.7,
    'MDH': 29.7 + 2.3 * 2 * 310 * 2.26 * (0.8) /1000 , # MDH delta proton correction in cytosol (nH 2.3 RT * delta pH)
    'ADK1': 0.3, # Equilibrator value ?!
    'NDPK1m': -2.7, # Equilibrator value  (EC: 2.7.4.6)
    'FADH2ETC': -70/2, # Equilibrator  value ?
    'G3PD1': 22.6, # Equilibrator value ?!?
    'r0205': -59.7, # Equilibrator value ?!?
    'PiC': 2.3 * 310 * 2.26 * (-0.8) / 1000 ,  # Charge NEUTRAL transport of phophate -> only proton force (nH 2.3 RT * delta pH)
    'PPA': -19, # 
    'FACOAL160i': -15, # Lehninge
    'BDHm': 8.0, # Equilibrator value (EC: 1.1.1.30)
    'OCOAT1m': 12.6, # Equilibrator value (EC: 2.8.3.5)
    'ACACT1rm': 25, # Equilibrator value (EC: 2.3.1.9)
    'C160CPT1': -2.2, # Equilibrator value (EC: 2.3.1.21 reverse)
    'C160CPT1': 2.2, # Equilibrator value (EC: 2.3.1.21)
}
# Converstion to kcal/mol
scaling = 0.239006
for r_id, dg in tca_thermodynamics.items():
    dgo = reduced_model.delta_gstd.get_by_id(r_id).variable
    try:
        dgo.ub = dg * scaling + 0.1
        dgo.lb = dg * scaling - 0.1
    except ValueError:
        dgo.lb = dg * scaling - 0.1
        dgo.ub = dg * scaling + 0.1

    reduced_model.optimize()
    print(f"{r_id} : {dgo.lb} < {dgo.primal} < {dgo.ub} kcal/mol")
    

sol = reduced_model.optimize()
# Out:
# PDHm : -8.0828004 < -8.0828004 < -7.8828004 kcal/mol
# CSm : -7.819893799999999 < -7.819893799999999 < -7.6198938 kcal/mol
# ACONTm : 3.0787798 < 3.0787798 < 3.2787798 kcal/mol
# ICDHxm : 2.29006 < 2.29006 < 2.49006 kcal/mol
# AKGDm : -8.106701 < -8.106701 < -7.906701 kcal/mol
# SUCOAS1m : -0.7931174 < -0.5931174 < -0.5931174 kcal/mol
# r0509 : -5.8600446 < -5.8600446 < -5.660044600000001 kcal/mol
# FUMm : -1.0082228 < -1.0082228 < -0.8082228 kcal/mol
# MDHm : 6.9984782 < 6.9984782 < 7.198478199999999 kcal/mol
# MDH : 7.614685381248 < 7.614685381248 < 7.814685381247999 kcal/mol
# ADK1 : -0.02829820000000001 < -0.02829820000000001 < 0.17170180000000002 kcal/mol
# NDPK1m : -0.7453162 < -0.7453162 < -0.5453162 kcal/mol
# FADH2ETC : -8.465209999999999 < -8.465209999999999 < -8.26521 kcal/mol
# G3PD1 : 5.3015356 < 5.3015356 < 5.5015355999999995 kcal/mol
# r0205 : -14.3686582 < -14.3686582 < -14.168658200000001 kcal/mol
# PiC : -0.40810359062400003 < -0.40810359062400003 < -0.208103590624 kcal/mol
# PPA : -4.641114 < -4.641114 < -4.441114000000001 kcal/mol
# FACOAL160i : -3.68509 < -3.68509 < -3.48509 kcal/mol
# BDHm : 1.8120479999999999 < 1.8120479999999999 < 2.012048 kcal/mol
# OCOAT1m : 2.9114755999999997 < 2.9114755999999997 < 3.1114756 kcal/mol
# ACACT1rm : 5.8751500000000005 < 5.968633070210639 < 6.07515 kcal/mol
# C160CPT1 : 0.4258132 < 0.4258132 < 0.6258132 kcal/mol

# %%
# Make sure that transporters dont have unrealistic equilibrium constants
EPSILON_DG = 1e-6

exceptions = ['ATPS4mi','CYOR_u10mi','CYOOm2i','NADH2_u10mi','PiC','Na_dummy']
# Print transport deltaG0
for r in reduced_model.reactions:
    if r.thermo['isTrans'] and (r.id not in exceptions):
        try:
            print(f"{r.id} : {r.reaction} {r.thermo['deltaGR']} kcal/mol")
            dgo = reduced_model.delta_gstd.get_by_id(r.id)
            dgo.variable.ub = r.thermo['deltaGR'] + EPSILON_DG
            dgo.variable.lb = r.thermo['deltaGR'] - EPSILON_DG
        except KeyError:
            pass

# Limit the delta G error of Fatty-acid oxidation
reduced_model.delta_gstd.FAOXC160.variable.lb = -44 - 2
reduced_model.delta_gstd.FAOXC160.variable.ub = -44 + 2

# Delta G Channel by default with memebrane potential -3 kcal/mol 
# This leads to NA accumulation at equilibrium 
# This channel is there to model other processes that transport sodium back to the cytosol
# We expect that the membrane potential fully to depnds on the existance of a redox potential
# This delta G is set to 0
reduced_model.delta_gstd.Na_channel.variable.ub = 0
reduced_model.delta_gstd.Na_channel.variable.lb = 0

reduced_model.optimize()
# Out:
# AKGMALtm : akg_m + mal_L_c <=> akg_c + mal_L_m 0.0012994733051527874 kcal/mol
# ASPGLUm : asp_L_m + glu_L_c + h_c --> asp_L_c + glu_L_m + h_m -4.550942133284353 kcal/mol
# ATPtm : adp_c + atp_m <=> adp_m + atp_c -3.4080072060923845 kcal/mol
# BHBt : bhb_e + h_e <=> bhb_c + h_c 0.27246543423115455 kcal/mol
# BHBtm : bhb_c + h_c <=> bhb_m + h_m -1.0902086818095462 kcal/mol
# CO2tm : co2_c <=> co2_m 0.0 kcal/mol
# FATP1t : h_c + hdca_c <=> h_e + hdca_e -0.27196881644598747 kcal/mol
# GLCt1r : glc_D_e <=> glc_D_c 0.0 kcal/mol
# H2Otm : h2o_c <=> h2o_m 0 kcal/mol
# L_LACtm : h_c + lac_L_c <=> h_m + lac_L_m -1.0905609991066534 kcal/mol
# O2tm : o2_c <=> o2_m 0.0 kcal/mol
# PYRt2m : h_c + pyr_c <=> h_m + pyr_m -1.0906689378694914 kcal/mol
# r2435 : crn_m + pmtcrn_c <=> crn_c + pmtcrn_m 1.3372807472933346e-05 kcal/mol
# CO2t : co2_e <=> co2_c 0.0 kcal/mol
# H2Ot : h2o_e <=> h2o_c 0 kcal/mol
# L_LACt2r : h_e + lac_L_e <=> h_c + lac_L_c 0.27261990058316243 kcal/mol
# NAt3_1 : h_e + na1_c <=> h_c + na1_e 0.27266723446737373 kcal/mol
# O2t : o2_e <=> o2_c 0.0 kcal/mol
# NaH_antiport : h_c + na1_m <=> h_m + na1_c -1.0906689378694914 kcal/mol
# Na_channel : na1_c <=> na1_m -3.4591499999999997 kcal/mol
# PYRt : h_e + pyr_e <=> h_c + pyr_c 0.2726672344673773 kcal/mol
# <Solution 173.379 at 0x7f9609b06250>

# %%
# Curate the thermodynamic fo the beta oxidation pathway

beta_oxidation_reactions = ['ACOAD16m', 'ECH16m', 'KAS16m', 'THIO16m',
                            'ACOAD14m', 'ECH14m', 'KAS14m', 'THIO14m',
                            'ACOAD12m', 'ECH12m', 'KAS12m', 'THIO12m',
                            'ACOAD10m', 'ECH10m', 'KAS10m', 'THIO10m',
                            'ACOAD8m', 'ECH8m', 'KAS8m', 'THIO8m',
                            'ACOAD6m', 'ECH6m', 'KAS6m', 'THIO6m',
                            'ACOAD4m', 'ECH4m', 'KAS4m',]

# Reduce the error to 0.1 kcal/mol
EPSILON_DG = 0.1
for r_id in beta_oxidation_reactions:
    dgo_computed = reduced_model.reactions.get_by_id(r_id).thermo['deltaGR']
    dgo = reduced_model.delta_gstd.get_by_id(r_id)
    dgo.variable.ub = dgo_computed + EPSILON_DG
    dgo.variable.lb = dgo_computed - EPSILON_DG

    reduced_model.optimize()

# %%
12.529995909336051 / 0.239006
# Out:
# 52.425445006970754

# %%
aspartate_malate_shuttle = ['MDH', 'ASPTA', 'ASPTAm', 'MDHm', 'ASPGLUm', 'AKGMALtm', 'PYRt']
# print thermodynamics for aspartate malate shuttle

for r_id in aspartate_malate_shuttle:
    r = reduced_model.reactions.get_by_id(r_id)
    dgo = reduced_model.delta_gstd.get_by_id(r_id).variable
    print(f"{r_id} :  {r.reaction} , {dgo.lb} < {dgo.primal} < {dgo.ub} kcal/mol")
# Out:
# MDH :  mal_L_c + nad_c <=> 2.0 h_c + nadh_c + oaa_c , 7.614685381248 < 7.614685381248 < 7.814685381247999 kcal/mol
# ASPTA :  akg_c + asp_L_c <=> glu_L_c + oaa_c , -3.143823519664295 < -3.143823519664295 < 0.856176480335705 kcal/mol
# ASPTAm :  akg_m + asp_L_m <=> glu_L_m + oaa_m , -3.144983579865368 < -3.144983579865368 < 0.855016420134632 kcal/mol
# MDHm :  mal_L_m + nad_m <=> 2.0 h_m + nadh_m + oaa_m , 6.9984782 < 6.9984782 < 7.198478199999999 kcal/mol
# ASPGLUm :  asp_L_m + glu_L_c + h_c --> asp_L_c + glu_L_m + h_m , -4.5509431332843535 < -4.5509431332843535 < -4.550941133284353 kcal/mol
# AKGMALtm :  akg_m + mal_L_c <=> akg_c + mal_L_m , 0.0012984733051527874 < 0.0012984733051527874 < 0.0013004733051527873 kcal/mol
# PYRt :  h_e + pyr_e <=> h_c + pyr_c , 0.2726662344673773 < 0.2726662344673773 < 0.27266823446737726 kcal/mol

# %%
import numpy as np
from pytfa.optim.constraints import ModelConstraint

# Force ATP/ADP ratio to be 10
# Cytosolic ATP/ADP ratio
# https://pubmed.ncbi.nlm.nih.gov/749453/


expression = reduced_model.log_concentration.atp_c.variable - reduced_model.log_concentration.adp_c.variable
id_='atp_c_adp_c_ratio'

reduced_model.add_constraint(ModelConstraint,
                        hook=reduced_model,
                        expr=expression,
                        id_=id_, 
                        lb=np.log(8), 
                        ub=np.log(10),
                        )
print(f"Integrate cytosolic ATP/ADP ratio: 8-10 ")
sol = reduced_model.optimize()
print(f"ATP yield: {sol.objective_value}")


# Force ATP/ADP ratio to bearround 2 and 8
# Cytosolic ATP/ADP ratio
# https://www.mdpi.com/1422-0067/23/10/5550


expression = reduced_model.log_concentration.atp_m.variable - reduced_model.log_concentration.adp_m.variable
id_='atp_m_adp_m_ratio'

reduced_model.add_constraint(ModelConstraint,
                        hook=reduced_model,
                        expr=expression,
                        id_=id_, 
                        lb=np.log(2), 
                        ub=np.log(8),
                        )
print(f"Integrate mitochondrial ATP/ADP ratio: 2-8")
sol = reduced_model.optimize()
sol = reduced_model.optimize()
print(f"ATP yield: {sol.objective_value}")

# mitochondrial GTP/GDP ratio
expression = reduced_model.log_concentration.gtp_m.variable - reduced_model.log_concentration.gdp_m.variable

reduced_model.add_constraint(ModelConstraint,
                        hook=reduced_model,
                        expr=expression,
                        id_='gtp_m_gdp_m_ratio', 
                        lb=np.log(10), 
                        ub=np.log(300),
                        )
print(f"Integrate mitochondrial GTP/GDP ratio: 10-300")
reduced_model.optimize()
sol = reduced_model.optimize()
print(f"ATP yield: {sol.objective_value}")        

# mitochondrial NAD/NADH ratio
expression = reduced_model.log_concentration.nad_m.variable - reduced_model.log_concentration.nadh_m.variable

reduced_model.add_constraint(ModelConstraint,
                        hook=reduced_model,
                        expr=expression,
                        id_='nad_m_nadh_m_ratio', 
                        lb=np.log(5), 
                        ub=np.log(20),
                        )
print(f"Integrate mitochondrial NAD+/NADH ratio: 5-20")
reduced_model.optimize()
sol = reduced_model.optimize()
print(f"ATP yield: {sol.objective_value}")  

# Cytoplasmic NAD/NADH ratio
expression = reduced_model.log_concentration.nad_c.variable - reduced_model.log_concentration.nadh_c.variable

reduced_model.add_constraint(ModelConstraint,
                        hook=reduced_model,
                        expr=expression,
                        id_='nad_c_nadh_c_ratio', 
                        lb=np.log(500), 
                        ub=np.log(1000),
                        )

# This is not in general but for muscle 
print(f"Integrate cytoplasmic NAD+/NADH ratio: 500-1000")
reduced_model.optimize()
sol = reduced_model.optimize()
print(f"ATP yield: {sol.objective_value}")  


# Add constaints on the glutamate and astpatate partitioning in mitochondria and cytosol
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5030821/#:~:text=The%20most%20abundant%20metabolites%20were,et%20al.%2C%202015).

# Glutamtmate is about factor 100 - 1000 more abundant in the cytosol than in the mitochondria
expression = reduced_model.log_concentration.glu_L_c.variable - reduced_model.log_concentration.glu_L_m.variable

reduced_model.add_constraint(ModelConstraint,
                        hook=reduced_model,
                        expr=expression,
                        id_='glu_L_c_glu_L_m_ratio', 
                        lb=np.log(10), 
                        ub=np.log(1000),
                        )

print(f"Integrate cytoplasmic/mitochondrial glutamate ratio: 100-5000")
reduced_model.optimize()
sol = reduced_model.optimize()
print(f"ATP yield: {sol.objective_value}")

# Aspartate is about factor 0.1-10 
expression = reduced_model.log_concentration.asp_L_c.variable - reduced_model.log_concentration.asp_L_m.variable

reduced_model.add_constraint(ModelConstraint,
                        hook=reduced_model,
                        expr=expression,
                        id_='asp_L_c_asp_L_m_ratio', 
                        lb=np.log(0.01), 
                        ub=np.log(10),
                        )

print(f"Integrate cytoplasmic/mitochondrial aspartate ratio: 0.1-10")
sol = reduced_model.optimize()
# Out:
# Integrate cytosolic ATP/ADP ratio: 8-10
# ATP yield: 173.37931034482762
# Integrate mitochondrial ATP/ADP ratio: 2-8
# ATP yield: 173.37931034482762
# Integrate mitochondrial GTP/GDP ratio: 10-300
# ATP yield: 173.37931034482762
# Integrate mitochondrial NAD+/NADH ratio: 5-20
# ATP yield: 173.37931034482762
# Integrate cytoplasmic NAD+/NADH ratio: 500-1000
# ATP yield: 173.37931034482762
# Integrate cytoplasmic/mitochondrial glutamate ratio: 100-5000
# ATP yield: 173.37931034482762
# Integrate cytoplasmic/mitochondrial aspartate ratio: 0.1-10

# %%
# List all the compounds that have no thermo 
for met in reduced_model.metabolites:
    if met.thermo['deltaGf_std'] >= 1000:
        print(met.id, met.thermo)
        print('-------------------')

# Find all reactions that dont have a thermo constraint that are not boundary reactions
thermo_reactions = [r.id for r in reduced_model.delta_g]

for rxn in reduced_model.reactions:
    #if not rxn.id in thermo_reactions and not rxn in reduced_model.boundary:
    if rxn.thermo['computed'] == False and not rxn in reduced_model.boundary:
        print(rxn.id, rxn.reaction)
        print('-------------------')

# %%
# Run a flux analysis to see how constrain is the flux 
from pytfa.analysis import variability_analysis
from pytfa.optim.variables import DeltaG

#FVA = variability_analysis(reduced_model, kind='reactions')
TVA = variability_analysis(reduced_model, kind=DeltaG)
# Out:
# 2024-12-16 10:43:17,275 - thermomodel_Recon3thermoCurated - INFO - Beginning variability analysis for variable of type <class 'pytfa.optim.variables.DeltaG'>
# minimizing: 100%|██████████| 91/91 [00:01<00:00, 67.97it/s]
# maximizing: 100%|██████████| 91/91 [00:01<00:00, 71.35it/s]

# %%
# Flux constraints for the core model 
RER = 0.79
fraction_of_whole_body_o2 = 0.8
total_carbon_contribution_modeled = 0.8

o2_uptake = 2.0 * fraction_of_whole_body_o2 * total_carbon_contribution_modeled
co2_production = o2_uptake * RER 

# oxygen uptake about of redmuscle 80% of total oxygen uptake 2000 nmol/min/gBW -2 umol/min/gDW
reduced_model.reactions.EX_o2_e.bounds = (-o2_uptake, -o2_uptake)
# Constrain the RET to about 0.8 of the total glucose uptake
reduced_model.reactions.EX_co2_e.bounds = (co2_production, co2_production)
reduced_model.reactions.CO2tm.bounds = (-10, -co2_production*0.5)

#Dont waste ATP by cycling via ACYP
reduced_model.reactions.ACYP.bounds = (0,0)

# MDHm is forward driven (TCA is turning)
reduced_model.reactions.MDHm.bounds = (0.1, 100)


reduced_model.optimize()

#Add constraints for CO2 production in the core model of and glucose, lactate
glucose_direct_contribution = 0.042 / 6 / total_carbon_contribution_modeled
lactate_direct_contribution = 0.24 / 3 / total_carbon_contribution_modeled
bhb_direct_contribution = 0.021 / 4 / total_carbon_contribution_modeled * 2.0 # Acetoacetate is converted to 2 BHB

# Glucose uptake in redmuscle 40 nmol/min/gDW -> This seem to be more accutalty reflecting that glucose uptake is about 10%  of the oxygen uptake
glucose_uptake_est = 40/1000 
reduced_model.reactions.EX_glc_D_e.bounds = (-glucose_uptake_est, -glucose_uptake_est)
reduced_model.reactions.EX_bhb_e.bounds = (-co2_production * bhb_direct_contribution, -co2_production * bhb_direct_contribution)

# Produce minimal ammounts of pyruvate
reduced_model.reactions.PYRt.bounds = (1e-3, 2e-3)

sol = reduced_model.optimize()

# %%
# Make a pi chart of the carbon contribution of the different metabolites
# Uptakes rates 
import pandas as pd

rows = ['GLCt1r',  'L_LACt2r','FATP1t', 'BHBt', 'PYRt'] 
carbons = pd.Series({ 'GLCt1r': 6, 'L_LACt2r': 3, 'PYRt':3 , 'FATP1t': 16, 'BHBt': 4, })[rows]

uptake_flux = sol.fluxes[rows].abs() * carbons[rows]

# 25% others 
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()
ax.pie(uptake_flux, labels=uptake_flux.index, autopct='%1.1f%%', startangle=90)

plt.show()

# %%
# Function to integrate metabolite concentrations
import numpy as np 
from optlang.exceptions import SolverError

def set_concentration(model, metabolite_id, concentration, uncertainty=0.1, unit='mmol/L', std=None):
    if unit == 'mmol/L':
        concentration = concentration / 1000
        if not std is None:
            std = std/1000
        if not np.isscalar(uncertainty):
            uncertainty = [x/1000 for x in uncertainty]
    else:
        raise ValueError('Unit not supported')
    

    metabolite = model.log_concentration.get_by_id(metabolite_id)
    compartment = model.metabolites.get_by_id(metabolite_id).compartment
    c_min = reduced_model.compartments[compartment]['c_min']

    var = metabolite.variable

    if (std is None) and np.isscalar(uncertainty):
        try:            
            var.ub = np.log(concentration + concentration * uncertainty)
            var.lb = np.log(concentration - concentration * uncertainty)
        except ValueError:
            var.lb = np.log(concentration - concentration * uncertainty)
            var.ub = np.log(concentration + concentration * uncertainty)
    elif (std is None) and (len(uncertainty) == 2):
        try:
            var.lb = np.log(uncertainty[0])
            var.ub = np.log(uncertainty[1])
        except ValueError:
            var.ub = np.log(uncertainty[1])
            var.lb = np.log(uncertainty[0])
    elif std is not None:
        try:
            var.ub = np.log(concentration + std)
            lb = np.log(concentration - std) if concentration - std > c_min else np.log(c_min)
            var.lb = lb
        except ValueError:
            lb = np.log(concentration - std) if concentration - std > c_min else np.log(c_min)
            var.lb = lb
            var.ub = np.log(concentration + std)
    else:
        raise ValueError('Uncertainty not supported')
        
    # Test the constraint
    try:
        sol = model.optimize()
        if sol.status != 'optimal':
            raise ValueError(f'Constraining {metabolite_id} to {concentration} failed.')
    except:
        raise ValueError(f'Constraning {metabolite_id} to {concentration} failed.')

# %%
from pytfa.optim.variables import LogConcentration
TVA = variability_analysis(reduced_model, kind=LogConcentration)
# Out:
# 2024-12-16 10:43:20,387 - thermomodel_Recon3thermoCurated - INFO - Beginning variability analysis for variable of type <class 'pytfa.optim.variables.LogConcentration'>
# minimizing: 100%|██████████| 111/111 [00:00<00:00, 123.11it/s]
# maximizing: 100%|██████████| 111/111 [00:01<00:00, 75.57it/s]

# %%
# Integrate serum metabolomics 

# Glucose concentration in serum
glucose_concentration = 5.5 # mmol/L 
# Lactate concentration in serum
lactate_concentration = 0.75 # mmol/L
# Fatty-acid concentration in serum
fatty_acid_concentration = 0.5 # mmol/L
# Ketone concentration in serum 
ketone_concentration = 0.1 # mmol/L

# pyruvate concentration in serum
pyruvate_concentration = 0.12 # mmol/L

# O2 concentration in serum 80 mmHG -> to mmol/L
T = 273.15 + 37
o2_concentration_artery = 1e3 * 80/ (62.36367*T)
o2_concentration_muscle = 1e3 * 30/ (62.36367*T)

# CO2 concentration in serum 40 mmHG -> to mmol/L
co2_concentration = 1e3 * 40/ (62.36367*T)


set_concentration(reduced_model, 'glc_D_e', glucose_concentration, uncertainty=0.1)

set_concentration(reduced_model, 'lac_L_e', lactate_concentration, uncertainty=0.1)
#set_concentration(reduced_model, 'lac_L_c', lactate_concentration*0.8, uncertainty=0.9)

set_concentration(reduced_model, 'pyr_e', pyruvate_concentration, uncertainty=0.1)

set_concentration(reduced_model, 'hdca_e', fatty_acid_concentration, uncertainty=0.1)


set_concentration(reduced_model, 'bhb_e', ketone_concentration, uncertainty=0.1)    

set_concentration(reduced_model, 'o2_e', o2_concentration_artery, uncertainty=0.1)
set_concentration(reduced_model, 'o2_c', o2_concentration_muscle*0.75, uncertainty=0.1)
set_concentration(reduced_model, 'o2_m', o2_concentration_muscle*0.5, uncertainty=0.1)

set_concentration(reduced_model, 'co2_e', co2_concentration, uncertainty=0.1)   

# Sodium
na1_concentration_serum = 140 # mmol/L
na1_concentration_muscle = 10 # mmol/L
na1_concentration_mitochondria = 8 # mmol/L

set_concentration(reduced_model, 'na1_c', na1_concentration_muscle, uncertainty=0.0)
set_concentration(reduced_model, 'na1_m', na1_concentration_mitochondria, uncertainty=0.0)

# Phosphate concentration 5 mM 
# https://www.frontiersin.org/journals/physiology/articles/10.3389/fphys.2012.00463/full
set_concentration(reduced_model, 'pi_c', 5, 0.9)
set_concentration(reduced_model, 'pi_m', 12, 0.5)


reduced_model.optimize()
# Out:
# <Solution 6.129 at 0x7f96008722e0>

# %%
# Run a flux analysis to see how constrain is the flux distribution
from pytfa.analysis import variability_analysis
FVA = variability_analysis(reduced_model, kind='reactions')
# Out:
# 2024-12-16 10:43:23,104 - thermomodel_Recon3thermoCurated - INFO - Beginning variability analysis for variable of type reactions
# minimizing: 100%|██████████| 102/102 [00:00<00:00, 227.36it/s]
# maximizing: 100%|██████████| 102/102 [00:00<00:00, 265.59it/s]

# %%
#reduced_model.solver.problem.conflict.refine()
#reduced_model.solver.problem.conflict.write('bla.txt')

# %%
# Read the tissue metabolomics data
import pandas as pd
tissue_metabolomics = pd.read_csv('./../data/C57BL6_6hr_fasted.csv')

tissue_type = 'Soleus'

tissue_samples = tissue_metabolomics.Tissue == tissue_type
tissue_metabolomics[tissue_samples]
# Out:
#     Tissue  a-ketoglutarate   alanine  arginine  asparagine  aspartate  \
# 48  Soleus           164.82   8830.95    166.09      125.35     343.31
# 49  Soleus           270.08  20673.02    135.75      175.04    1091.43
# 50  Soleus           221.14  18248.35    190.22      196.63    2462.46
# 51  Soleus           218.93  18785.52    180.17      183.07    1992.65
#
#     citrate  fumarate  glutamate  glutamine  ...  methionine  phenylalanine  \
# 48   506.18     41.44    4334.70    3264.68  ...       32.66          58.63
# 49   441.79     63.14    4171.56    2943.38  ...       42.34          78.29
# 50   390.77     93.81    2686.22    2526.05  ...       65.75          70.51
# 51   354.46     95.38    3141.48    2557.69  ...       61.26          60.67
#
#     proline  pyruvate  serine  succinate  threonine  tryptophan  tyrosine  \
# 48    86.84    375.54  261.30      74.22     197.54       15.66     43.59
# 49    86.92    560.16  315.55     173.60     236.77       14.86     71.53
# 50   124.80    717.46  374.81     183.29     302.36       17.03    115.98
# 51   123.48    698.18  370.55     181.01     277.40       17.02     95.59
#
#     valine
# 48  171.44
# 49  184.09
# 50  187.89
# 51  191.78
#
# [4 rows x 27 columns]

# %%
# Metabolomics from taras paper (we use soleus concentrtions)
set_concentration(reduced_model, 'g6p_c', 0.45, uncertainty=0.9)
set_concentration(reduced_model, 'f6p_c', 0.45, uncertainty=0.9) # (Assuumes 50/50 splot in g6p anf f6p)
set_concentration(reduced_model, 'fdp_c', 0.44, std=0.18)
set_concentration(reduced_model, 'g3p_c', 0.43, uncertainty=0.9)

reduced_model.optimize()
# Out:
# <Solution 6.129 at 0x7f96007b8e80>

# %%
TVA = variability_analysis(reduced_model, kind=DeltaG)

# Transform from log to log10 -> scale with log10(e)
TVA['minimum'] = TVA.minimum * np.log10(np.exp(1))
TVA['maximum'] = TVA.maximum * np.log10(np.exp(1))

TVA['range'] = TVA.maximum - TVA.minimum
TVA['mid'] = (TVA.maximum + TVA.minimum) / 2

# Print a list of delta G with low range
for met_id in TVA.index:
    entry = TVA.loc[met_id]
    if abs(entry['minimum']) < 1e-3 and abs(entry['maximum']) < 1e-3:
        print(met_id, entry['minimum'], entry['mid'], entry['maximum'])
        print('-------------------')
# Out:
# 2024-12-16 10:43:24,066 - thermomodel_Recon3thermoCurated - INFO - Beginning variability analysis for variable of type <class 'pytfa.optim.variables.DeltaG'>
# minimizing: 100%|██████████| 91/91 [00:02<00:00, 36.85it/s]
# maximizing: 100%|██████████| 91/91 [00:02<00:00, 45.12it/s]

# %%
metabolite_mapping = [
    ('a-ketoglutarate', ('akg_m', 100.0)),
    ('a-ketoglutarate', ('akg_c', 10.0)),
    ('citrate', ('cit_m', 2.0)),
    ('fumarate', ('fum_m', 2.0)),
    #('lactate', ('lac_L_c', 5.0)),
    #('lactate', ('lac_L_m', 5.0)),
    ('malate', ('mal_L_m', 100.0)),
    ('malate', ('mal_L_c', 10.0)),
    ('pyruvate', ('pyr_m', 100.0)),
    ('pyruvate', ('pyr_c', 100.0)),
    ('succinate', ('succ_m',  2.0)),
    #('glutamate', ('glu_L_m', 100.0)),
    ('glutamate', ('glu_L_c', 5.0)),
    #('aspartate', ('asp_L_m', 10.0)),
    ('aspartate', ('asp_L_c', 10.0)),
]

metabolites_to_map = list(set(m[0] for m in metabolite_mapping))
data_extracted = tissue_metabolomics[tissue_samples][metabolites_to_map] * 1e-3 # convert uM to mM 

# Plot the metabolomics data and the assumed bounds for the metabolites
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots()
# Plot all the data points 
sns.stripplot(data=data_extracted, ax=ax, jitter=0.2, color='black', alpha=0.5)

means = data_extracted.mean()

# Compute mitochondrial and cytosolic ranges -> mean/scaling , mean*scaling
ranges = []
for met, (met_id, scaling) in metabolite_mapping:
    mid = means[met]
    lb = mid / scaling
    ub = mid * scaling
    if met_id.endswith('_m'):
        ranges.append({'metabolite': met, 'lb': lb, 'ub': ub, 'compartment': 'mitochondrial'})
    else:
        ranges.append({'metabolite': met, 'lb': lb, 'ub': ub, 'compartment': 'cytosolic'})

ranges = pd.DataFrame(ranges)

# Plot the mitochondiral and cytosolic ranges as ractangles between lb and ub 
ranges = ranges.set_index('metabolite')
mit_ranges = ranges[ranges.compartment == 'mitochondrial']
cyt_ranges = ranges[ranges.compartment == 'cytosolic']

plt.bar(mit_ranges.index, mit_ranges.ub - mit_ranges.lb, bottom=mit_ranges.lb, color='red', alpha=0.5)
plt.bar(cyt_ranges.index, cyt_ranges.ub - cyt_ranges.lb, bottom=cyt_ranges.lb, color='blue', alpha=0.5)

plt.yscale('log')

plt.xticks(rotation=90)

plt.ylabel('Concentration (mM)')

plt.show()

# %%
# # # Map the metabolomics data to the model
for metabolite_name, (metabolite_id, uncertainty_fac) in metabolite_mapping:
    concentration = data_extracted[metabolite_name].mean()
    uncertainty = data_extracted[metabolite_name].std()
    #print(f"{metabolite_name} concentration: {concentration} +/- {uncertainty*uncertainty_fac}")
    uncertainty = (concentration / uncertainty_fac, concentration * uncertainty_fac)
    set_concentration(reduced_model, metabolite_id, concentration, uncertainty=uncertainty)

# %%
# Carnitine concentration in Muscle 500 pmol/mg -> (1000g/L density of muscle) -> 500 uM
carnitine_concentration = 500e-3
set_concentration(reduced_model, 'crn_c', carnitine_concentration, 0.999)
set_concentration(reduced_model, 'crn_m', carnitine_concentration, 0.999)

# Long chain acyl-carnitine concentration 01 - 10 uM in Muscle 
# https://www.nature.com/articles/s41598-017-17797-x
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4274800/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4274800/
set_concentration(reduced_model, 'pmtcrn_c', 1.0e-3 , 0.999)
set_concentration(reduced_model, 'pmtcrn_m', 1.0e-3 , 0.999)

# acyl-CoA in Muscle < 5 uM
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4274800/
set_concentration(reduced_model, 'pmtcoa_c', 0.1e-3 , 0.9999)
set_concentration(reduced_model, 'pmtcoa_m', 1.0e-3 , 0.9999)

# Assume beta-oxidation intermetidates in the muscle < 1 uM
species = ['c4coa_m', 'c6coa_m', 'c8coa_m', 'c10coa_m', 'c12coa_m', 'c14coa_m',
           'c16enoylcoa_m', 'c14enoylcoa_m', 'c12enoylcoa_m', 'c10enoylcoa_m', 'c8enoylcoa_m', 'c6enoylcoa_m', 'c4enoylcoa_m',
           'c16hydroxyacylcoa_m', 'c14hydroxyacylcoa_m', 'c12hydroxyacylcoa_m', 'c10hydroxyacylcoa_m', 'c8hydroxyacylcoa_m', 'c6hydroxyacylcoa_m', 'c4hydroxyacylcoa_m',
           'c16ketoacylcoa_m', 'c14ketoacylcoa_m', 'c12ketoacylcoa_m', 'c10ketoacylcoa_m', 'c8ketoacylcoa_m', 'c6ketoacylcoa_m', ]

for s in species:
    set_concentration(reduced_model, s, 0.1e-3, 1-1e-6)


# CoA in Muscle
set_concentration(reduced_model, 'coa_c', 1.0e-3 , 0.9)
set_concentration(reduced_model, 'coa_m', 1.0e-3 , 0.9)


# Try glycerol-3 phosphate integration (assumed to quite abundand in muscle)
# https://www.nature.com/articles/s41387-018-0045-x -> 10 - 100 uM
set_concentration(reduced_model, 'glyc3p_c', 100e-3, 0.99)


sol = reduced_model.optimize()
print(sol.objective_value)
# Out:
# 6.099455714285716

# %%
np.exp(reduced_model.log_concentration.nad_c.variable.primal - reduced_model.log_concentration.nadh_c.variable.primal)
# Out:
# 499.999999999999

# %%
reduced_model.log_concentration.lac_L_c.variable.primal
# Out:
# -8.295734215013912

# %%
reduced_model.log_concentration.pyr_c.variable.primal
# Out:
# -12.044234447677619

# %%
reduced_model.delta_g.LDH_L.variable.primal
# Out:
# -9.999894245993346e-10

# %%
TVA = variability_analysis(reduced_model, kind=DeltaG)

# Transform from log to log10 -> scale with log10(e)
TVA['minimum'] = TVA.minimum * np.log10(np.exp(1))
TVA['maximum'] = TVA.maximum * np.log10(np.exp(1))

TVA['range'] = TVA.maximum - TVA.minimum
TVA['mid'] = (TVA.maximum + TVA.minimum) / 2

# Print a list of delta G with low range
for met_id in TVA.index:
    entry = TVA.loc[met_id]
    if abs(entry['minimum']) < 1e-3 and abs(entry['maximum']) < 1e-3:
        print(met_id, entry['minimum'], entry['mid'], entry['maximum'])
        print('-------------------')
# Out:
# 2024-12-16 10:43:29,825 - thermomodel_Recon3thermoCurated - INFO - Beginning variability analysis for variable of type <class 'pytfa.optim.variables.DeltaG'>
# minimizing: 100%|██████████| 91/91 [00:02<00:00, 33.17it/s]
# maximizing: 100%|██████████| 91/91 [00:02<00:00, 43.92it/s]
# DG_ICDHxm -4.3429031600746505e-10 -4.125753784411194e-10 -3.908604408747737e-10
# -------------------

# %%
# Print malate aspartate shuttle free ene
aspartate_malate_shuttle= ['MDH', 'ASPTA', 'ASPTAm', 'MDHm', 'ASPGLUm', 'AKGMALtm']
lactate_shuttle = ['LDH_L', 'LDH_Lm', 'PYRt2m','L_LACDcm' , 'PYRt']

for rxn_id in lactate_shuttle:
    entry = TVA.loc["DG_"+rxn_id]
    rxn = reduced_model.reactions.get_by_id(rxn_id)
    print(rxn_id,rxn.reaction, entry['minimum'], entry['maximum'])
    print('-------------------')
# Out:
# LDH_L lac_L_c + nad_c <=> 2.0 h_c + nadh_c + pyr_c -0.36727954725450823 5.148351291706918
# -------------------
# LDH_Lm lac_L_m + nad_m <=> 2.0 h_m + nadh_m + pyr_m 0.17439146084954385 7.636593875651427
# -------------------
# PYRt2m h_c + pyr_c <=> h_m + pyr_m -1.1553558168397902 -4.3428988401158323e-10
# -------------------
# L_LACDcm 2.0 ficytC_m + lac_L_c --> 2.0 focytC_m + 2.0 h_c + pyr_c -12.637281857071956 -6.126491935010244
# -------------------
# PYRt h_e + pyr_e --> h_c + pyr_c -0.6816838816795973 -4.341204808374122e-10
# -------------------

# %%
# Here we choose a flux profile

# Limit LDHm reverse
reduced_model.reactions.LDH_Lm.bounds = (-0.01, -0.001)

# Assume the direaction of all three shuttles
reduced_model.reactions.AKGMALtm.bounds = (0.01, 0.2)
reduced_model.reactions.G3PD1.bounds = (-0.2, -0.0)

# LDH-D (Fe2+) is not the dominant LDH in muscle 
reduced_model.reactions.L_LACDcm.bounds = (0.001, 0.002)

# Limit the NaH antiport
reduced_model.reactions.Na_channel.bounds = (2.0,  2.1)

sol = reduced_model.optimize()

# %%
# Run a flux analysis to see how constrain is the flux distribution
from pytfa.analysis import variability_analysis
FVA = variability_analysis(reduced_model, kind='reactions')
# Out:
# 2024-12-16 10:43:34,751 - thermomodel_Recon3thermoCurated - INFO - Beginning variability analysis for variable of type reactions
# minimizing: 100%|██████████| 102/102 [00:00<00:00, 217.89it/s]
# maximizing: 100%|██████████| 102/102 [00:00<00:00, 293.50it/s]

# %%
# Remove the reactions that cannot carry flux
EPSILON = 1e-6  
reactions_to_remove = [r for r in reduced_model.reactions if FVA.loc[r.id, 'minimum'] >= -EPSILON and FVA.loc[r.id, 'maximum'] <= EPSILON ]
print(reactions_to_remove)
reduced_model.remove_reactions(reactions_to_remove)
reduced_model.repair()

metabolites_to_remove = [m for m in reduced_model.metabolites if len(m.reactions) == 0]
reduced_model.remove_metabolites(metabolites_to_remove)
reduced_model.repair()

sol = reduced_model.optimize()
print(sol.objective_value)
# Out:
# [<Reaction FAOXC160 at 0x7f9610689340>, <Reaction NAt3_1 at 0x7f96106899d0>, <Reaction ACYP at 0x7f9610689b20>]
# 5.597955714285715

# %%
# Run a flux analysis to see how constrain is the flux 
from pytfa.analysis import variability_analysis
FVA = variability_analysis(reduced_model, kind='reactions')

# Plot the fluxes as bars starting at min and ending at max
FVA['range'] = FVA.maximum - FVA.minimum
FVA['mid'] = (FVA.maximum + FVA.minimum) / 2

fasted_fluxes = FVA['mid']
# Out:
# 2024-12-16 10:43:35,636 - thermomodel_Recon3thermoCurated - INFO - Beginning variability analysis for variable of type reactions
# minimizing: 100%|██████████| 99/99 [00:00<00:00, 178.87it/s]
# maximizing: 100%|██████████| 99/99 [00:00<00:00, 230.45it/s]

# %%
# Plot the flux variablity analysis
import matplotlib.pyplot as plt
import seaborn as sns

f = plt.figure(figsize=(10, 3))
plt.bar(FVA.index, FVA.range, bottom=FVA.minimum)
plt.scatter(FVA.index, FVA.mid, color='k', s=10)

# from cobra.flux_analysis.parsimonious import optimize_minimal_flux
# reduced_model.objective = reduced_model.problem.Objective(reduced_model.reactions.cyt_atp2adp.forward_variable, direction='max')
# sol = optimize_minimal_flux(reduced_model)
# plt.scatter(sol.fluxes.index, sol.fluxes, color='r', s=10)

plt.xticks(rotation=90)
plt.tight_layout()

plt.show()

# %%
# Print bidreactional reactions from FVA
for r in reduced_model.reactions:
    if FVA.loc[r.id, 'minimum'] < -EPSILON and FVA.loc[r.id, 'maximum'] > EPSILON:
        print(r.id, r.reaction, FVA.loc[r.id, ['minimum', 'maximum']].values)

# %%
# Force minimal flux of 1e-4 and deltaG of -1e-4
EPSILON_DG = 0.03 # kcal/mol
EPSILON_FLUX = 1e-3
sol = reduced_model.optimize()

for rxn in reduced_model.reactions:
    sol = reduced_model.optimize()
    primal_dg = None
    if FVA.loc[rxn.id].maximum > 0:

        rxn.bounds = (EPSILON_FLUX, rxn.bounds[1])
        try:
            deltaG = reduced_model.delta_g.get_by_id(rxn.id).variable
            deltaG.ub = -EPSILON_DG
        except KeyError:
            pass
            
    elif FVA.loc[rxn.id].minimum < 0:
        rxn.bounds = (rxn.bounds[0], -EPSILON_FLUX)
        try:
            deltaG = reduced_model.delta_g.get_by_id(rxn.id).variable
            deltaG.lb = EPSILON_DG
        except KeyError:
            pass
    else:
        raise ValueError(f"Somthing is really from with {rxn.id}")

    try:
        sol = reduced_model.optimize()
        if sol.status != 'optimal':
            raise SolverError(f"Failed to constrain {rxn.id} as {primal_dg}")
    except SolverError:
        raise SolverError(f"Failed to constrain {rxn.id} as {primal_dg}")

# %%
# Plot the flux variablity analysis
import matplotlib.pyplot as plt
import seaborn as sns

# Concentration of metabolites
from pytfa.optim.variables import LogConcentration
TVA = variability_analysis(reduced_model, kind=LogConcentration)
FVA = variability_analysis(reduced_model, kind='reactions')

# Plot the fluxes as bars starting at min and ending at max
plt.figure(figsize=(15, 5))

# Transform from log to log10 -> scale with log10(e)
TVA['minimum'] = TVA.minimum * np.log10(np.exp(1))
TVA['maximum'] = TVA.maximum * np.log10(np.exp(1))

TVA['range'] = TVA.maximum - TVA.minimum
TVA['mid'] = (TVA.maximum + TVA.minimum) / 2


plt.bar(TVA.index, TVA.range, bottom=TVA.minimum)
plt.scatter(TVA.index, TVA.mid, color='k', s=10)
plt.xticks(np.arange(len(TVA.index)), TVA.index, rotation=90)
plt.tight_layout()

plt.show()
# Out:
# 2024-12-16 10:43:38,243 - thermomodel_Recon3thermoCurated - INFO - Beginning variability analysis for variable of type <class 'pytfa.optim.variables.LogConcentration'>
# minimizing: 100%|██████████| 109/109 [00:00<00:00, 284.95it/s]
# maximizing: 100%|██████████| 109/109 [00:00<00:00, 243.41it/s]
# 2024-12-16 10:43:39,078 - thermomodel_Recon3thermoCurated - INFO - Beginning variability analysis for variable of type reactions
# minimizing: 100%|██████████| 99/99 [00:00<00:00, 361.80it/s]
# maximizing: 100%|██████████| 99/99 [00:00<00:00, 262.35it/s]

# %%
from pytfa.analysis import  apply_reaction_variability,     \
                            apply_generic_variability,      \
                            apply_directionality

from pytfa.optim.variables import DeltaG,DeltaGstd,LogConcentration
# Fesiblitity analysis
solution = reduced_model.optimize()


# TVA of the model
thermo_vars = [DeltaG,DeltaGstd,LogConcentration]
TVA = variability_analysis(reduced_model, kind=thermo_vars)


# Strip model of integers variables
fixed_directionality_model = apply_directionality(reduced_model, solution)
tight_model = apply_reaction_variability(fixed_directionality_model, FVA)
tight_model = apply_generic_variability (tight_model  , TVA)
# Out:
# 2024-12-16 10:43:40,164 - thermomodel_Recon3thermoCurated - INFO - Beginning variability analysis for variable of type <class 'pytfa.optim.variables.DeltaG'>
# minimizing:   0%|          | 0/88 [00:00<?, ?it/s]
# minimizing: 100%|██████████| 88/88 [00:00<00:00, 197.03it/s]
# maximizing: 100%|██████████| 88/88 [00:00<00:00, 388.46it/s]
# 2024-12-16 10:43:40,840 - thermomodel_Recon3thermoCurated - INFO - Beginning variability analysis for variable of type <class 'pytfa.optim.variables.DeltaGstd'>
# minimizing: 100%|██████████| 88/88 [00:00<00:00, 496.76it/s]
# maximizing: 100%|██████████| 88/88 [00:00<00:00, 454.19it/s]
# 2024-12-16 10:43:41,214 - thermomodel_Recon3thermoCurated - INFO - Beginning variability analysis for variable of type <class 'pytfa.optim.variables.LogConcentration'>
# minimizing: 100%|██████████| 109/109 [00:00<00:00, 343.18it/s]
# maximizing: 100%|██████████| 109/109 [00:00<00:00, 308.03it/s]

# %%
from pytfa.optim import strip_from_integer_variables
from pytfa.analysis import sample

continuous_model = strip_from_integer_variables(tight_model)
continuous_model.repair()
# Out:
# 2024-12-16 10:43:42,150 - thermomodel_Recon3thermoCurated - INFO - # Model initialized with units kcal/mol and temperature 298.15 K
# Is the cobra_model still integer ? False

# %%
continuous_model.solver.configuration.tolerances.feasibility = 1e-9
continuous_model.solver.configuration.tolerances.optimality = 1e-9
continuous_model.solver.configuration.tolerances.integrality = 1e-9

# %%
continuous_model.delta_g.FATP1t.variable.lb = 0.03
continuous_model.delta_g.FATP1t.variable.ub = 0.1

continuous_model.optimize()
# Out:
# <Solution 6.098 at 0x7f960adfce20>

# %%
# Gelta D constraints for glycolysis (Lehninger)
continuous_model.delta_g.HEX1.variable.ub = -20 * 0.239006
continuous_model.delta_g.HEX1.variable.lb = -33.4 * 0.239006

# Make sure PYK is fwd driven
continuous_model.delta_g.PYK.variable.ub = -10 * 0.239006
continuous_model.delta_g.PYK.variable.lb = -30 * 0.239006

# PFK 
continuous_model.delta_g.PFK.variable.ub = -10 * 0.239006
continuous_model.delta_g.PFK.variable.lb = -25 * 0.239006

continuous_model.optimize()
# Out:
# <Solution 6.098 at 0x7f9640fabf10>

# %%
# Rest of glycolysis close to equilibrium
continuous_model.delta_g.PGI.variable.lb = -0.5 * 0.239006 # Shu be very close to equilibrium
continuous_model.delta_g.FBA.variable.lb = -0.5 * 0.239006 # 6 in lehninger but we make it more reversible since glycolysis bearly active
continuous_model.delta_g.TPI.variable.lb = -0.5 * 0.239006 # Shu be very close to equilibrium
continuous_model.delta_g.PGM.variable.ub = 0.5 * 0.239006 # reverse annotated
continuous_model.delta_g.PGK.variable.ub = 0.5 * 0.239006 # reverse annotated
continuous_model.delta_g.GAPD.variable.lb = -0.5 * 0.239006
continuous_model.delta_g.ENO.variable.lb = -0.5 * 0.239006

continuous_model.optimize()
# Out:
# <Solution 6.098 at 0x7f9632868c10>

# %%
# Mitochondrial lactate transport close to equilibrium
continuous_model.delta_g.L_LACtm.variable.lb = 0.001 # kcal/mol
continuous_model.delta_g.L_LACtm.variable.ub = 0.01 # kcal/mol

# Latate transport L_LACt2r
continuous_model.delta_g.L_LACt2r.variable.lb = -0.5 # kcal/mol

continuous_model.optimize()
# Out:
# <Solution 6.098 at 0x7f9600a03280>

# %%
# Other considerations
# PDHm is thought to be displaced from equilibrium
continuous_model.delta_g.PDHm.variable.ub = -2 # kcal/mol

# SCCOAS is not regulated -> close to equilibrium
continuous_model.delta_g.SUCOAS1m.variable.ub = 0.5 # kcal/mol

# AConitase close to equilibrium
continuous_model.delta_g.ACONTm.variable.lb = -0.5 # kcal/mol

# Limit CPT1 and CPT2 to a small range 1-2 kcal/mol
continuous_model.delta_g.C160CPT2.variable.lb = -0.5 # kcal/mol
continuous_model.delta_g.C160CPT1.variable.lb = -0.5 # kcal/mol

# ADK1 / NDPK1mclose to equilibrium
continuous_model.delta_g.ADK1.variable.lb = -0.1 # kcal/mol
continuous_model.delta_g.NDPK1m.variable.ub = 0.5 # kcal/mol

# Limit irreverisblity of GPD1 and MDH
continuous_model.delta_g.MDH.variable.ub = 0.5

# Limit the irreversibility of the glycerol-3-phosphate shuttle
# continuous_model.delta_g.G3PD1.variable.ub = 2.5


continuous_model.optimize()
# Out:
# <Solution 6.098 at 0x7f96009fc940>

# %%
# Limit the displacement of the betaoxidation enzymes 
# KAS is most displaced (1 - 5 kcal/mol)
KAS_reactions = [r for r in continuous_model.reactions if 'KAS' in r.id]
for r in KAS_reactions:
    continuous_model.delta_g.get_by_id(r.id).variable.lb = -5
    sol = continuous_model.optimize()

    if sol.status != 'optimal':
        print(r.id, sol.status)
        print('-------------------')

# %%
# Limt the Hydratase setp in beta oxidation
# ECH
ECH_reactions = [r for r in continuous_model.reactions if 'ECH' in r.id]
for r in ECH_reactions:
    continuous_model.delta_g.get_by_id(r.id).variable.lb = -1.0

    if sol.status != 'optimal':
        print(r.id, sol.status)
        print('-------------------')

# %%
# Limit the Actyl-CoA dehydrogenase
ACAD_reactions = [r for r in continuous_model.reactions if 'ACOAD' in r.id]
for r in ACAD_reactions:
    continuous_model.delta_g.get_by_id(r.id).variable.lb = -0.5
    sol = continuous_model.optimize()

    if sol.status != 'optimal':
        print(r.id, sol.status)
        print('-------------------')

# %%
# Limit the Thiolase step in beta oxidation
# THIO
THIO_reactions = [r for r in continuous_model.reactions if 'THIO' in r.id]
for r in THIO_reactions:
    continuous_model.delta_g.get_by_id(r.id).variable.lb = -5
    sol = continuous_model.optimize()

    if sol.status != 'optimal':
        print(r.id, sol.status)
        print('-------------------')

# %%
# ELCTRON TRANSPORT CHAIN 
continuous_model.delta_g.NADH2_u10mi.variable.ub = -0.1 # kcal/mol
continuous_model.delta_g.CYOOm2i.variable.ub = -0.1 # kcal/mol

continuous_model.optimize()

# Displace the CYOR_u10mi a bit more from equilibrium
continuous_model.delta_g.CYOR_u10mi.variable.ub = -0.1 # kcal/mol

# Complex II like entry into ETC 
# Succinate dehydrogenase should be displced from equilibrium! 
continuous_model.delta_g.r0509.variable.ub = -0.1 # kcal/mol
continuous_model.delta_g.FADH2ETC.variable.ub = -0.1# kcal/mol

continuous_model.optimize()
# Out:
# <Solution 6.098 at 0x7f96328582b0>

# %%
# Make some assumption on the most importat 

# NAD concentration
nad_concentration = 1.5 # mM
set_concentration(continuous_model, 'nad_c', nad_concentration, uncertainty=0.9)
set_concentration(continuous_model, 'nad_m', nad_concentration, uncertainty=0.9)

# Assumption of OAA 10 uM rangge
set_concentration(continuous_model, 'oaa_m', 1e-3, 0.99)
set_concentration(continuous_model, 'oaa_c', 10e-3, 0.9)

# FAD concentration
fad_concentration = 10e-3# mM
set_concentration(continuous_model, 'fad_m', fad_concentration, uncertainty=0.9)
#set_concentration(continuous_model, 'fadh2_m', fad_concentration, uncertainty=0.99)


# GDP concentration
gdp_concentration = 0.05 # mM
set_concentration(continuous_model, 'gtp_m', gdp_concentration, uncertainty=0.5)

# ATP concentration 10 uM range
set_concentration(continuous_model, 'atp_c', 10e-3, uncertainty=0.5)

# Mitochondiral ATP concentration 
set_concentration(continuous_model, 'atp_m', 10e-3, uncertainty=0.5)

# Ubiqionone 40 uM range  https://www.nature.com/articles/pr2015124
set_concentration(continuous_model, 'q10h2_m' , 40e-3, uncertainty=0.5)
#set_concentration(continuous_model, 'q10_m' , 4e-3, uncertainty=0.9)

# Ferrocyto-chrome 1uM range
set_concentration(continuous_model, 'ficytC_m', 1e-3, uncertainty=0.5)

# # Acetocatete concentrion << Km of OCOAT1m
# set_concentration(continuous_model, 'acac_m', 10e-3, uncertainty=0.99)

# Accetoacetate CoA concentration in 1uM range
set_concentration(continuous_model, 'aacoa_m', 1e-3, uncertainty=0.9)

# Diphotphate 0.1 mM ?!
set_concentration(continuous_model, 'ppi_c', 0.1, 0.9)

# Intra cellular glucose should be lowish 1-10 uM
set_concentration(continuous_model, 'glc_D_c',  50e-3, 0.99)

# Actetyl coa in 500 uM range
set_concentration(continuous_model, 'accoa_m', 500e-3, 0.99)

# succoa_m 10 uM range
set_concentration(continuous_model, 'succoa_m', 50e-3, 0.99)

# mitochondiral co2 abour 2 fold hiher than extracellular + gradient
set_concentration(continuous_model, 'co2_m', 1.5 * co2_concentration, 0.1)
set_concentration(continuous_model, 'co2_c', 1.25 * co2_concentration, 0.1)

# %%
TVA = variability_analysis(continuous_model, kind=LogConcentration)
# Out:
# 2024-12-16 10:43:42,844 - thermomodel_Recon3thermoCurated - INFO - Beginning variability analysis for variable of type <class 'pytfa.optim.variables.LogConcentration'>
# minimizing: 100%|██████████| 109/109 [00:00<00:00, 2231.55it/s]
# maximizing: 100%|██████████| 109/109 [00:00<00:00, 4681.91it/s]

# %%
# Sample the concnetrations and fluxes in the continuous_model
sampling = sample(continuous_model, 1000 , processes=4, seed=0,  method='optgp')
# Out:
# 2024-12-16 10:43:43,043 - thermomodel_Recon3thermoCurated - continuous - INFO - # Model initialized with units kcal/mol and temperature 298.15 K
# 2024-12-16 10:43:43,941 - thermomodel_Recon3thermoCurated - continuous - INFO - # Model initialized with units kcal/mol and temperature 298.15 K
# 2024-12-16 10:43:44,669 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ACACT1rm
# 2024-12-16 10:43:44,672 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ACONTm_reverse_8079b
# 2024-12-16 10:43:44,674 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable AKGDm_reverse_ec8eb
# 2024-12-16 10:43:44,675 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable AKGMALtm_reverse_8c3a3
# 2024-12-16 10:43:44,676 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ASPGLUm_reverse_b29bf
# 2024-12-16 10:43:44,676 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ASPTAm
# 2024-12-16 10:43:44,680 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ATPtm_reverse_b45b1
# 2024-12-16 10:43:44,681 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable BDHm_reverse_8031c
# 2024-12-16 10:43:44,682 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable BHBt_reverse_f8ad6
# 2024-12-16 10:43:44,684 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable BHBtm_reverse_5356f
# 2024-12-16 10:43:44,685 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable C160CPT1_reverse_f2a81
# 2024-12-16 10:43:44,686 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable C160CPT2_reverse_90c4e
# 2024-12-16 10:43:44,687 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable CO2tm
# 2024-12-16 10:43:44,690 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable CSm_reverse_bb3a1
# 2024-12-16 10:43:44,690 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable EX_bhb_e
# 2024-12-16 10:43:44,692 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable EX_hdca_e
# 2024-12-16 10:43:44,695 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable FACOAL160i_reverse_c6d09
# 2024-12-16 10:43:44,695 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable FATP1t
# 2024-12-16 10:43:44,702 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable FUMm_reverse_5e620
# 2024-12-16 10:43:44,712 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable GLCt1r_reverse_252c0
# 2024-12-16 10:43:44,713 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable H2Otm
# 2024-12-16 10:43:44,727 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ICDHxm_reverse_14a38
# 2024-12-16 10:43:44,728 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable LDH_Lm
# 2024-12-16 10:43:44,732 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable L_LACDcm_reverse_7bb6e
# 2024-12-16 10:43:44,732 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable L_LACtm
# 2024-12-16 10:43:44,735 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable MDHm_reverse_80605
# 2024-12-16 10:43:44,736 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable NDPK1m
# 2024-12-16 10:43:44,742 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable O2tm_reverse_fe4d6
# 2024-12-16 10:43:44,746 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable OCOAT1m_reverse_15b22
# 2024-12-16 10:43:44,747 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable PDHm_reverse_31d17
# 2024-12-16 10:43:44,749 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable PYRt2m_reverse_fb762
# 2024-12-16 10:43:44,749 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable SUCOAS1m
# 2024-12-16 10:43:44,752 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable r0205_reverse_094b1
# 2024-12-16 10:43:44,753 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable r0509_reverse_81b5b
# 2024-12-16 10:43:44,754 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable r2435_reverse_b4a47
# 2024-12-16 10:43:44,756 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable FADH2ETC_reverse_35e23
# 2024-12-16 10:43:44,757 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ADK1_reverse_a6f90
# 2024-12-16 10:43:44,759 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ASPTA_reverse_36525
# 2024-12-16 10:43:44,759 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable CO2t
# 2024-12-16 10:43:44,762 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ENO_reverse_40eea
# 2024-12-16 10:43:44,764 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable EX_co2_e_reverse_d0466
# 2024-12-16 10:43:44,764 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable EX_h_e
# 2024-12-16 10:43:44,766 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable EX_h2o_e_reverse_3ced4
# 2024-12-16 10:43:44,766 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable EX_lac_L_e
# 2024-12-16 10:43:44,771 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable EX_o2_e
# 2024-12-16 10:43:44,776 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable FBA_reverse_84806
# 2024-12-16 10:43:44,777 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable G3PD1
# 2024-12-16 10:43:44,783 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable GAPD_reverse_459c1
# 2024-12-16 10:43:44,784 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable H2Ot
# 2024-12-16 10:43:44,791 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable HEX1_reverse_25efa
# 2024-12-16 10:43:44,795 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable L_LACt2r_reverse_45197
# 2024-12-16 10:43:44,798 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable O2t_reverse_4d957
# 2024-12-16 10:43:44,801 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable PGI_reverse_27efc
# 2024-12-16 10:43:44,802 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable PGK
# 2024-12-16 10:43:44,806 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable PGM
# 2024-12-16 10:43:44,808 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable PPA_reverse_c5293
# 2024-12-16 10:43:44,809 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable TPI_reverse_c2c3b
# 2024-12-16 10:43:44,812 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable LDH_L_reverse_fa844
# 2024-12-16 10:43:44,813 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable MDH
# 2024-12-16 10:43:44,818 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable PFK_reverse_d24a6
# 2024-12-16 10:43:44,820 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable PYK_reverse_bc8ff
# 2024-12-16 10:43:44,821 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable EX_glc_D_e
# 2024-12-16 10:43:44,823 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ATPS4mi_reverse_d277b
# 2024-12-16 10:43:44,824 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable CYOR_u10mi_reverse_b5db8
# 2024-12-16 10:43:44,826 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable NADH2_u10mi_reverse_5572e
# 2024-12-16 10:43:44,827 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable CYOOm2i_reverse_4375f
# 2024-12-16 10:43:44,828 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable cyt_atp2adp_reverse_15cc2
# 2024-12-16 10:43:44,830 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable PiC_reverse_fe5dd
# 2024-12-16 10:43:44,831 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable NaH_antiport_reverse_aa26c
# 2024-12-16 10:43:44,832 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable Na_channel_reverse_6870b
# 2024-12-16 10:43:44,834 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable PYRt_reverse_6fee7
# 2024-12-16 10:43:44,834 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable EX_pyr_e
# 2024-12-16 10:43:44,836 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ACOAD16m_reverse_cb24e
# 2024-12-16 10:43:44,837 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ECH16m_reverse_c41d9
# 2024-12-16 10:43:44,838 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable KAS16m_reverse_ca070
# 2024-12-16 10:43:44,839 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable THIO16m_reverse_33e1e
# 2024-12-16 10:43:44,840 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ACOAD14m_reverse_9aa7a
# 2024-12-16 10:43:44,842 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ECH14m_reverse_3fd35
# 2024-12-16 10:43:44,843 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable KAS14m_reverse_a52c3
# 2024-12-16 10:43:44,844 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable THIO14m_reverse_e5f44
# 2024-12-16 10:43:44,845 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ACOAD12m_reverse_588ec
# 2024-12-16 10:43:44,846 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ECH12m_reverse_6e70e
# 2024-12-16 10:43:44,847 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable KAS12m_reverse_74833
# 2024-12-16 10:43:44,848 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable THIO12m_reverse_6f951
# 2024-12-16 10:43:44,849 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ACOAD10m_reverse_3a0c7
# 2024-12-16 10:43:44,850 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ECH10m_reverse_668c6
# 2024-12-16 10:43:44,851 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable KAS10m_reverse_c1d03
# 2024-12-16 10:43:44,853 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable THIO10m_reverse_e407a
# 2024-12-16 10:43:44,854 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ACOAD8m_reverse_7fb6f
# 2024-12-16 10:43:44,856 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ECH8m_reverse_a49cc
# 2024-12-16 10:43:44,857 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable KAS8m_reverse_ea7e4
# 2024-12-16 10:43:44,858 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable THIO8m_reverse_6b619
# 2024-12-16 10:43:44,859 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ACOAD6m_reverse_d2934
# 2024-12-16 10:43:44,860 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ECH6m_reverse_c9b86
# 2024-12-16 10:43:44,862 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable KAS6m_reverse_dd63e
# 2024-12-16 10:43:44,863 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable THIO6m_reverse_28e7d
# 2024-12-16 10:43:44,865 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ACOAD4m_reverse_50e66
# 2024-12-16 10:43:44,866 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable ECH4m_reverse_ed402
# 2024-12-16 10:43:44,869 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable KAS4m_reverse_0e7fe
# 2024-12-16 10:43:44,869 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable LC_h2o_c
# 2024-12-16 10:43:44,871 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable LC_h2o_m
# 2024-12-16 10:43:44,873 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable LC_h_m
# 2024-12-16 10:43:44,873 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable LC_h_c
# 2024-12-16 10:43:44,893 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable LC_h_e
# 2024-12-16 10:43:44,913 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable LC_h2o_e
# 2024-12-16 10:43:44,946 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable LC_na1_c
# 2024-12-16 10:43:44,952 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable DGo_ASPGLUm
# 2024-12-16 10:43:44,954 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable DGo_ATPtm
# 2024-12-16 10:43:44,956 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable DGo_BHBt
# 2024-12-16 10:43:44,958 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable DGo_BHBtm
# 2024-12-16 10:43:44,964 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable DGo_FATP1t
# 2024-12-16 10:43:44,969 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable DGo_L_LACtm
# 2024-12-16 10:43:44,975 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable DGo_PYRt2m
# 2024-12-16 10:43:44,987 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable DGo_L_LACt2r
# 2024-12-16 10:43:45,001 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable LC_na1_m
# 2024-12-16 10:43:45,014 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable DGo_NaH_antiport
# 2024-12-16 10:43:45,014 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable DG_Na_channel
# 2024-12-16 10:43:45,015 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable DGo_Na_channel
# 2024-12-16 10:43:45,016 - thermomodel_Recon3thermoCurated - continuous - INFO - skipping fixed variable DGo_PYRt

# %%
TVA = variability_analysis(continuous_model, kind=LogConcentration)

# Plot the fluxes as bars starting at min and ending at max
plt.figure(figsize=(5, 15))

# Convert from ln to log10
TVA['minimum'] = np.log10(np.exp(TVA.minimum))
TVA['maximum'] = np.log10(np.exp(TVA.maximum))
sampling_log10 = np.log10(np.exp(sampling))

TVA['range'] = TVA.maximum - TVA.minimum
TVA['mid'] = (TVA.maximum + TVA.minimum) / 2

# TVA sort by range
TVA = TVA.sort_values('range', ascending=True)

LC_MEDIAN = sampling_log10.median()[TVA.index]
LC_UQ = sampling_log10.quantile(0.95)[TVA.index]
LC_LQ = sampling_log10.quantile(0.05)[TVA.index]


plt.barh(TVA.index, TVA.range, left=TVA.minimum)
plt.errorbar( LC_MEDIAN, TVA.index, xerr=[LC_MEDIAN - LC_LQ, LC_UQ - LC_MEDIAN], fmt='o', color='k', ecolor='k', capsize=5)
# Align the xticks with the metabolites names
plt.yticks(np.arange(0,len(TVA.index)),  TVA.index,)
plt.tight_layout()
plt.show()
# Out:
# 2024-12-16 10:43:50,299 - thermomodel_Recon3thermoCurated - INFO - Beginning variability analysis for variable of type <class 'pytfa.optim.variables.LogConcentration'>
# minimizing: 100%|██████████| 109/109 [00:00<00:00, 1606.88it/s]
# maximizing: 100%|██████████| 109/109 [00:00<00:00, 4557.48it/s]

# %%
TVA.loc[['LC_bhb_e', 'LC_bhb_c', 'LC_bhb_m']]
# Out:
#            minimum   maximum    range       mid
# LC_bhb_e -4.045757 -3.958607  0.08715 -4.002182
# LC_bhb_c -4.286633 -4.180463  0.10617 -4.233548
# LC_bhb_m -3.508975 -3.402805  0.10617 -3.455890

# %%
from pytfa.optim.variables import DeltaG
# PLot the TVA of the reaction deltaG
TVA = variability_analysis(continuous_model, kind=DeltaG)

# Plot the fluxes as bars starting at min and ending at max
plt.figure(figsize=(15, 5))

TVA['range'] = TVA.maximum - TVA.minimum
TVA['mid'] = (TVA.maximum + TVA.minimum) / 2

plt.bar(TVA.index, TVA.range, bottom=TVA.minimum)

LC_MEDIAN = sampling.median()[TVA.index]
LC_UQ = sampling.quantile(0.95)[TVA.index]
LC_LQ = sampling.quantile(0.05)[TVA.index]

plt.errorbar(TVA.index, LC_MEDIAN, yerr=[LC_MEDIAN - LC_LQ, LC_UQ - LC_MEDIAN], fmt='o', color='k', ecolor='k', capsize=5)

# Plot the 0 line 
plt.axhline(0, color='k', linestyle='--')

plt.xticks(np.arange(0,len(TVA.index)),  TVA.index, rotation=90)
plt.tight_layout()


plt.ylim(-10, 10)
# Out:
# 2024-12-16 10:43:50,841 - thermomodel_Recon3thermoCurated - INFO - Beginning variability analysis for variable of type <class 'pytfa.optim.variables.DeltaG'>
# minimizing: 100%|██████████| 88/88 [00:00<00:00, 1101.63it/s]
# maximizing: 100%|██████████| 88/88 [00:00<00:00, 4212.49it/s]
# (-10.0, 10.0)

# %%
from pytfa.optim.variables import DeltaG
# PLot the TVA of the reaction fluxes
TVA = variability_analysis(continuous_model, kind='reaction')

# Plot the fluxes as bars starting at min and ending at max
plt.figure(figsize=(15, 5))

TVA['range'] = TVA.maximum - TVA.minimum
TVA['mid'] = (TVA.maximum + TVA.minimum) / 2

plt.bar(TVA.index, TVA.range, bottom=TVA.minimum)

LC_MEDIAN = sampling.median()[TVA.index]
LC_UQ = sampling.quantile(0.95)[TVA.index]
LC_LQ = sampling.quantile(0.05)[TVA.index]

plt.errorbar(TVA.index, LC_MEDIAN, yerr=[LC_MEDIAN - LC_LQ, LC_UQ - LC_MEDIAN], fmt='o', color='k', ecolor='k', capsize=5)

# Plot the 0 line 
plt.axhline(0, color='k', linestyle='--')

plt.xticks(np.arange(0,len(TVA.index)),  TVA.index, rotation=90)
plt.tight_layout()
# Out:
# 2024-12-16 10:43:51,348 - thermomodel_Recon3thermoCurated - INFO - Beginning variability analysis for variable of type reaction
# minimizing: 100%|██████████| 99/99 [00:00<00:00, 903.90it/s]
# maximizing: 100%|██████████| 99/99 [00:00<00:00, 2203.14it/s]

# %%
f, ax = plt.subplots(2,2, figsize=(9,6))

fluxes = sampling.iloc[:, 0:2*len(continuous_model.reactions):2] - sampling.iloc[:, 1:2*len(continuous_model.reactions)+1:2].values


fluxes.plot.scatter('LDH_L', 'LDH_Lm', alpha=0.5, ax =ax[0,0])
fluxes.plot.scatter('G3PD1', 'LDH_L', alpha=0.5, ax =ax[0,1])
fluxes.plot.scatter('AKGMALtm','G3PD1',  alpha=0.5, ax =ax[1,0])
fluxes.plot.scatter('G3PD1', 'LDH_Lm', alpha=0.5, ax =ax[1,1])

# for a in ax.flatten():
#     a.set_xlim(0,0.2)
#     a.set_ylim(0,0.2)

FVA.loc['PYRt2m']
plt.tight_layout()

# %%
#Scatter for LC_pmtcoa_c and LC_pmtcoa_m
f, ax = plt.subplots(1,2, figsize=(7,3))

sampling.plot.scatter('LC_asp_L_c', 'LC_akg_c', alpha=0.5, ax =ax[0])
sampling.plot.scatter('LC_asp_L_c', 'LC_glu_L_c', alpha=0.5, ax =ax[1]) 

plt.tight_layout()
plt.show()

# %%
reduced_model.delta_gstd.L_LACtm
# Out:
# -1.0905599991066535 <= DGo_L_LACtm <= -1.0905599991066535

# %%
# Compute turnover rates metabolite / ( consumption flux) 
# Scaling parameters
CONCENTRATION_SCALING = 1e3 # 1 mol to 1 mmol
TIME_SCALING = 1 # 1min
DENSITY = 1200 # g/L 
# TODO SCALE THIS NICELY
GDW_GWW_RATIO = 1.0 # Fluxes are in gBW concentration in gMW 

# To test how close to zero the dxdt is
flux_scaling_factor = 1e-6 / (GDW_GWW_RATIO / DENSITY) \
                        * CONCENTRATION_SCALING \
                        / TIME_SCALING


def compute_turnover(met, model, sampling):
    fluxes = sampling.iloc[:, 0:2*len(continuous_model.reactions):2] - sampling.iloc[:, 1:2*len(continuous_model.reactions)+1:2].values
    
    # Compute reverible fluxes from dG vf = v * (1 - exp(dG/RT))
    forward_flux = [fluxes[r] * 1.0  / ( 1 - np.exp(sampling['DG_'+ r] / model.RT)  ) 
                    if 'DG_'+r in sampling.columns else fluxes[r]  for r in fluxes.columns]
    forward_flux = pd.concat(forward_flux, axis=1)  
    forward_flux.columns = [r for r in fluxes.columns]

    reverse_flux = [fluxes[r] * - np.exp(sampling['DG_'+ r] / model.RT)  / ( 1- np.exp(sampling['DG_'+ r] / model.RT) ) 
                    if 'DG_'+r in sampling.columns else fluxes[r]*0.0  for r in fluxes.columns]
    reverse_flux = pd.concat(reverse_flux, axis=1)
    reverse_flux.columns = [r for r in fluxes.columns]

    # Test flux
    r = 'BHBtm'
    print(forward_flux[r].mean(), reverse_flux[r].mean(), fluxes[r].mean())

    # Reactions that consume the metabolite in this sample
    consumption_flux_1 = [forward_flux[rxn.id]*rxn.metabolites[met] for rxn in met.reactions if any( forward_flux[rxn.id]*rxn.metabolites[met] < 0)]
    consumption_flux_2 = [reverse_flux[rxn.id]*rxn.metabolites[met] for rxn in met.reactions if any( reverse_flux[rxn.id]*rxn.metabolites[met] < 0)]
    consumption_flux = consumption_flux_1 + consumption_flux_2
    consumption_flux = pd.concat(consumption_flux, axis=1).sum(axis=1) * flux_scaling_factor

    concentration = np.exp(sampling.loc[:,'LC_'+met.id]) * CONCENTRATION_SCALING

    return consumption_flux / concentration

# Compute the turnover rates for each metabolite
turnover = [compute_turnover( m , continuous_model, sampling=sampling) for m in continuous_model.metabolites]
turnover = -1 * pd.concat(turnover, axis=1)  
turnover.columns = [m.id for m in continuous_model.metabolites]
# Out:
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239
# 0.05648049617219631 -0.053443661630890066 0.003036834541306239

# %%
# Make alist of all turn over rates that are conistantly low < 4.0 
# exclude h2o and na1
low_turnover = [m for m in turnover.columns[(turnover.abs().mean() < .1)] if not m.endswith("_e")] 

# Plot the turnover rates as a boxplot
f, ax = plt.subplots(figsize=(8, 5))
sns.boxplot(data=turnover[low_turnover], ax=ax)
plt.xticks(rotation=90)
plt.show()

# %%
# Print all reaction with a deltaG_std  > +/- 10 kcal/mol
for rxn in continuous_model.reactions:
    if rxn.thermo['deltaGR'] > 5 and not rxn in continuous_model.boundary:
        print(rxn.id, rxn.reaction, rxn.thermo)
# Out:
# ACACT1rm 2.0 accoa_m <-- aacoa_m + coa_m {'isTrans': False, 'computed': True, 'deltaGR': 7.0560000000002105, 'deltaGRerr': 1.087366929789572}
# ADK1 amp_c + atp_c + h_c --> 2.0 adp_c {'isTrans': False, 'computed': True, 'deltaGR': 10.24962080568946, 'deltaGRerr': 2}
# FBA fdp_c --> dhap_c + g3p_c {'isTrans': False, 'computed': True, 'deltaGR': 5.604831372302954, 'deltaGRerr': 1.231339855604455}
# PYK adp_c + h_c + pep_c --> atp_c + pyr_c {'isTrans': False, 'computed': True, 'deltaGR': 5.609472160844774, 'deltaGRerr': 0.654304974763298}
# CYOR_u10mi 2.0 ficytC_m + 2.0 h_m + q10h2_m --> 2.0 focytC_m + 4.0 h_c + q10_m {'isTrans': True, 'computed': True, 'deltaGR': 6.5556627684669095, 'deltaGrxn': -11.643612983011053, 'deltaGRerr': 2.9916129428788074}
# NADH2_u10mi 6.0 h_m + nadh_m + q10_m --> 4.0 h_c + nad_m + q10h2_m {'isTrans': True, 'computed': True, 'deltaGR': 23.341805367861973, 'deltaGrxn': -3.957108259354982, 'deltaGRerr': 3.07450548869245}
# ACOAD16m fad_m + h_m + pmtcoa_m --> c16enoylcoa_m + fadh2_m {'isTrans': False, 'computed': True, 'deltaGR': 14.07999590933612, 'deltaGRerr': 2.236466713367315}
# ACOAD14m c14coa_m + fad_m + h_m --> c14enoylcoa_m + fadh2_m {'isTrans': False, 'computed': True, 'deltaGR': 12.529995909335923, 'deltaGRerr': 2.2747710566120714}
# ACOAD12m c12coa_m + fad_m + h_m --> c12enoylcoa_m + fadh2_m {'isTrans': False, 'computed': True, 'deltaGR': 12.529995909335824, 'deltaGRerr': 2.2747710566120714}
# ACOAD10m c10coa_m + fad_m + h_m --> c10enoylcoa_m + fadh2_m {'isTrans': False, 'computed': True, 'deltaGR': 12.529995909336165, 'deltaGRerr': 2.2747710566120714}
# ACOAD8m c8coa_m + fad_m + h_m --> c8enoylcoa_m + fadh2_m {'isTrans': False, 'computed': True, 'deltaGR': 12.529995909336051, 'deltaGRerr': 2.2747710566120714}
# ACOAD6m c6coa_m + fad_m + h_m --> c6enoylcoa_m + fadh2_m {'isTrans': False, 'computed': True, 'deltaGR': 12.529995909336051, 'deltaGRerr': 2.2747710566120714}
# ACOAD4m c4coa_m + fad_m + h_m --> c4enoylcoa_m + fadh2_m {'isTrans': False, 'computed': True, 'deltaGR': 12.529995909336051, 'deltaGRerr': 2.2747710566120714}

# %%
# Print all reactions that use amp_c
for rxn in continuous_model.reactions:
    if 'amp_c' in [m.id for m in rxn.metabolites]:
        print(rxn.id, rxn.reaction, rxn.thermo)
# Out:
# FACOAL160i atp_c + coa_c + hdca_c --> amp_c + h_c + pmtcoa_c + ppi_c {'isTrans': False, 'computed': True, 'deltaGR': -21.838258329698704, 'deltaGRerr': 1.2316793413871974}
# ADK1 amp_c + atp_c + h_c --> 2.0 adp_c {'isTrans': False, 'computed': True, 'deltaGR': 10.24962080568946, 'deltaGRerr': 2}

# %%
# Write the samples to a csv file
sampling.to_csv( redgem_file_name.replace('.json','_tfa_sampling.csv'), index=False)

# %%
# Save the continuous model
from pytfa.io.json import save_json_model
save_json_model(continuous_model, redgem_file_name.replace('.json', '_continuous.json'))

# %%
# This as an attempt not really makes sense
# dissipation = sum([ r.variable * reduced_model.reactions.get_by_id(r.id).reverse_variable 
#                - r.variable * reduced_model.reactions.get_by_id(r.id).forward_variable 
#                for r in reduced_model.delta_g])

# # Objective function
# reduced_model.objective = reduced_model.problem.Objective(dissipation, direction='min')

# reduced_model.solver.problem.parameters.optimalitytarget.set(3)

# reduced_model.optimize()

# %% [markdown]
# # Integrate fed state fluxes into the continous models

# %%
# Relax the bounds but keep the directionality of dGs and fluxes
for reaction in continuous_model.reactions:
    if reaction.upper_bound > 0:
        reaction.bounds = (EPSILON_FLUX, 100)
    elif reaction.lower_bound < 0:
        reaction.bounds = (-100, -EPSILON_FLUX)

# %%
# Flux constraints for the core model 
# TODO 

RER = 0.9
fraction_of_whole_body_o2 = 0.8
total_carbon_contribution_modeled = 0.80

o2_uptake = 2.0 * fraction_of_whole_body_o2 * total_carbon_contribution_modeled
co2_production = o2_uptake * RER 

# oxygen uptake about of redmuscle 80% of total oxygen uptake 2000 nmol/min/gBW -2 umol/min/gDW
# continuous_model.reactions.EX_o2_e.bounds = (-o2_uptake, -o2_uptake)
# Constrain the RET to about 0.8 of the total glucose uptake
continuous_model.reactions.EX_co2_e.bounds = (co2_production, co2_production)

#Add constraints for CO2 production in the core model of and glucose, lactate
glucose_direct_contribution = 0.23 / 6 / total_carbon_contribution_modeled 
lactate_direct_contribution = 0.22 / 3 / total_carbon_contribution_modeled
bhb_direct_contribution = 0.008 / 4 / total_carbon_contribution_modeled

# Note we should consider over all glucose oxidation in fed animals it seems that the direct contribution is under estimating 
# Glucose oxidation

continuous_model.reactions.EX_glc_D_e.bounds = (-co2_production * glucose_direct_contribution, -co2_production * glucose_direct_contribution)
continuous_model.reactions.EX_lac_L_e.bounds = (-co2_production * lactate_direct_contribution, -co2_production * lactate_direct_contribution)
continuous_model.reactions.EX_bhb_e.bounds = (-co2_production * bhb_direct_contribution, -co2_production * bhb_direct_contribution)
sol = continuous_model.optimize()

# %%
# Run and plot the flux variablity analysis
FVA = variability_analysis(continuous_model, kind='reactions')

# Plot the fluxes as bars starting at min and ending at max
plt.figure(figsize=(15, 5))
FVA['range'] = FVA.maximum - FVA.minimum
FVA['mid'] = (FVA.maximum + FVA.minimum) / 2

plt.bar(FVA.index, FVA.range, bottom=FVA.minimum)
plt.scatter(FVA.index, FVA.mid, color='k', s=10)
plt.xticks(np.arange(len(FVA.index)), FVA.index, rotation=90)

plt.tight_layout()

fed_fluxes = FVA['mid']
# Out:
# 2024-12-16 10:43:57,969 - thermomodel_Recon3thermoCurated - INFO - Beginning variability analysis for variable of type reactions
# minimizing: 100%|██████████| 99/99 [00:00<00:00, 1365.97it/s]
# maximizing: 100%|██████████| 99/99 [00:00<00:00, 2318.24it/s]

# %%
# Save the two mid flux profiles to a file
import pandas as pd 
df = pd.DataFrame([fasted_fluxes, fed_fluxes], index=['fasted','fed']).T
df.to_csv(redgem_file_name.replace('.json','_char_flux_profiles.csv'))

# %%
# Compute the mean carbon flux from fed fed state predition 

mean_carbon_flux_fed = df.loc[:,'fed'].loc[rows].abs() * carbons
mean_carbon_flux_fasted = df.loc[:,'fasted'].loc[rows].abs() * carbons


# Add a column that accounts for 25% of the total flux and label it as 'other'
mean_carbon_flux_fed['other'] = mean_carbon_flux_fed.sum() * (1/0.80 - 1)
mean_carbon_flux_fasted['other'] = mean_carbon_flux_fasted.sum() * (1/0.80 - 1)

# A pie chart shoeing the distribution of the mean carbon flux:
fig, ax = plt.subplots(1,2)
mean_carbon_flux_fed.plot.pie(ax=ax[0], subplots=True, figsize=(5,5), autopct='%1.1f%%', startangle=90)
mean_carbon_flux_fasted.plot.pie(ax=ax[1], subplots=True, figsize=(5,5), autopct='%1.1f%%', startangle=90)

rer_fed = - df.loc['EX_co2_e','fed'] / df.loc['EX_o2_e','fed']
rer_fasted = - df.loc['EX_co2_e','fasted'] / df.loc['EX_o2_e','fasted']

# Note that this RER is based on 80% oxygen consumptuion
ax[0].set_title(f"RER fed: {rer_fed:.2f}")
ax[1].set_title(f"RER fasted: {rer_fasted:.2f}")
# Out:
# Text(0.5, 1.0, 'RER fasted: 0.79')

# %%
rer_fed = - df.loc['EX_co2_e','fed'] / df.loc['EX_o2_e','fed']

# %% [markdown]
# #### Sanity Checks on electron transports delta Gs

# %%
# Compute the redox potential of the NADH/NAD+ couple in the model
# NAD+ + H+ + 2e- ->  NADH
dG = continuous_model.metabolites.nad_c.thermo['deltaGf_std'] + continuous_model.metabolites.h_c.thermo['deltaGf_std'] - continuous_model.metabolites.nadh_c.thermo['deltaGf_std']
# Convert to V
# ΔG=−nFE 
# 1kcal = 4.184e3 J
F = 96485/4.184e3
n = 2

E = dG / (n * F)
E
# Out:
# -0.3165590506296296

# %%
# Compute the redox potential of the NADH/NAD+ couple in the model
# FAD + 2H+ + 2e- -> FADH2 (currently FAD is deprotonated so missing an H+)
dG = continuous_model.metabolites.fad_m.thermo['deltaGf_std'] + 3*continuous_model.metabolites.h_m.thermo['deltaGf_std'] - continuous_model.metabolites.fadh2_m.thermo['deltaGf_std']
# Convert to V
# ΔG=−nFE 
# 1kcal = 4.184e3 J
F = 96485/4.184e3
n = 2

E = dG / (n * F)
E
# Out:
# -0.19426133595895678

# %%
# Compute the redox potential of the Cytochrome couple in the model
# cyt c (Fe3+) + e- -> cyt c (Fe2+)
dG = continuous_model.metabolites.ficytC_m.thermo['deltaGf_std']  - continuous_model.metabolites.focytC_m.thermo['deltaGf_std']
# Convert to V
# ΔG=−nFE 
# 1kcal = 4.184e3 J
F = 96485/4.184e3
n = 2

E = dG / (n * F)
E
# Out:
# 0.12499999999999999

# %%
# Compute the redox potential of the Q10/Q10H2 couple in the model
# Q10 + 2H+ + 2e- -> Q10H2 
dG = continuous_model.metabolites.q10_m.thermo['deltaGf_std'] + 2*continuous_model.metabolites.h_m.thermo['deltaGf_std'] - continuous_model.metabolites.q10h2_m.thermo['deltaGf_std']
# Convert to V
# ΔG=−nFE 
# 1kcal = 4.184e3 J
F = 96485/4.184e3
n = 2

E = dG / (n * F)
E
# Out:
# 0.05724081463439945
