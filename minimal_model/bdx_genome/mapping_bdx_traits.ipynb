# %%
import pandas as pd 

snip_data = pd.read_table('BXD_current_rev050423.geno', skiprows=23, header=0, sep='\t')
# Out:
# /var/folders/n5/kq0k2frx06l30kyysqmgk1lw0000gn/T/ipykernel_13496/1823066130.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   snip_data = pd.read_table('BXD_current_rev050423.geno', skiprows=23, header=0, sep='\t')

# %%
# trait data

# %%
snip_data
# Out:
#       Chr           Locus      cM          Mb BXD1 BXD2 BXD5 BXD6 BXD8 BXD9  \
# 0       1  rsm10000000001    0.00    3.001490    B    B    D    D    D    B
# 1       1      rs31443144    0.11    3.010274    B    B    D    D    D    B
# 2       1       rs6269442    0.21    3.492195    B    B    D    D    D    B
# 3       1      rs32285189    0.32    3.511204    B    B    D    D    D    B
# 4       1     rs258367496    0.43    3.659804    B    B    D    D    D    B
# ...    ..             ...     ...         ...  ...  ...  ...  ...  ...  ...
# 21051   X      rs31638776  102.87  167.394896    B    B    B    D    B    B
# 21052   X  rsm10000014694  102.98  168.364884    B    B    B    D    B    B
# 21053   X  rsm10000014695  114.11  170.828902    B    B    D    D    B    D
# 21054   X  rsm10000014696  114.22  170.870157    B    B    D    D    B    D
# 21055   X  rsm10000014697  114.77  170.872015    B    B    D    D    B    D
#
# ...

# %%
# Use genereralized linear model

# %%
snip_data
# Out:
#        1       rs3677817    2.99    5.185979  B B.1  D D.1 D.2 B.2  ... D.92  \
# 0      1  rsm10000000121    3.10    5.315486  B   B  D   D   D   B  ...    D
# 1      1  rsm10000000011    3.31    5.316455  B   B  D   D   D   B  ...    D
# 2      1      rs47937185    3.53    5.316776  B   B  D   D   D   B  ...    D
# 3      1  rsm10000000012    3.63    5.323006  B   B  D   D   D   B  ...    D
# 4      1  rsm10000000148    3.74    5.521533  B   B  D   D   D   B  ...    D
# ...   ..             ...     ...         ... ..  .. ..  ..  ..  ..  ...  ...
# 21027  X      rs31638776  102.87  167.394896  B   B  B   D   B   B  ...    D
# 21028  X  rsm10000014694  102.98  168.364884  B   B  B   D   B   B  ...    D
# 21029  X  rsm10000014695  114.11  170.828902  B   B  D   D   B   D  ...    H
# 21030  X  rsm10000014696  114.22  170.870157  B   B  D   D   B   D  ...    H
# 21031  X  rsm10000014697  114.77  170.872015  B   B  D   D   B   D  ...    H
#
# ...
